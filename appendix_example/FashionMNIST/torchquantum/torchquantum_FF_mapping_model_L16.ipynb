# %%
import time
import os
import copy

# PyTorch
import torch
import torch.nn as nn
import torch.nn.functional as F

import torch.optim as optim
from torch.optim import lr_scheduler
import torchvision
from torchvision import datasets, transforms
import torchvision.transforms as transforms

## Distributed training
import torch.distributed as dist
from torch.utils.data.distributed import DistributedSampler
from torch.nn.parallel import DistributedDataParallel as DDP

# # Pennylane
# import pennylane as qml
# from pennylane import numpy as np
import torchquantum as tq
import numpy as np 



torch.manual_seed(42)
np.random.seed(42)

# Plotting
import matplotlib.pyplot as plt


import itertools

# OpenMP: number of parallel threads.
# os.environ["OMP_NUM_THREADS"] = "1"

device = torch.device("cuda:0" if torch.cuda.is_available() else "cpu")


### Classical target model initialization ###

# Hyperparameters
batch_size = 200
learning_rate = 0.001
num_epochs = 1

# Data loading and preprocessing
transform = transforms.Compose([transforms.ToTensor(), transforms.Normalize((0.5,), (0.5,))])

train_dataset = datasets.FashionMNIST(root='./data', train=True, transform=transform, download=True)
train_loader = torch.utils.data.DataLoader(dataset=train_dataset, batch_size=batch_size, shuffle=True)

test_dataset = datasets.FashionMNIST(root='./data', train=False, transform=transform, download=True)
test_loader = torch.utils.data.DataLoader(dataset=test_dataset, batch_size=batch_size, shuffle=False)

# Define the CNN model
class CNNModel(nn.Module):
    def __init__(self):
        super(CNNModel, self).__init__()
        self.conv1 = nn.Conv2d(1, 8, kernel_size=5)
        self.pool = nn.MaxPool2d(kernel_size=2, stride=2)
        self.conv2 = nn.Conv2d(8, 12, kernel_size=5)
        self.fc1 = nn.Linear(12*4*4, 20)
        self.fc2 = nn.Linear(20, 10)
        
    def forward(self, x):
        x = self.pool(self.conv1(x))
        x = self.pool(self.conv2(x))
        x = x.view(x.size(0), -1) # [N, 32 * 8 * 8]
        x = self.fc1(x)
        x = self.fc2(x)
        
        return x

# Instantiate the model and loss function
model = CNNModel()
criterion = nn.CrossEntropyLoss()
optimizer = optim.Adam(model.parameters(), lr=learning_rate)

# Training loop
for epoch in range(num_epochs):
    for i, (images, labels) in enumerate(train_loader):
        optimizer.zero_grad()
        outputs = model(images)
        loss = criterion(outputs, labels)
        loss.backward()
        optimizer.step()

        if (i+1) % 100 == 0:
            print(f"Epoch [{epoch+1}/{num_epochs}], Step [{i+1}/{len(train_loader)}], Loss: {loss.item():.4f}")


# Testing train loop
model.eval()
correct = 0
total = 0

loss_train_list = []
with torch.no_grad():
    for images, labels in train_loader:
        outputs = model(images)
        loss_train = criterion(outputs, labels).cpu().detach().numpy()
        loss_train_list.append(loss_train)
        _, predicted = torch.max(outputs.data, 1)
        total += labels.size(0)
        correct += (predicted == labels).sum().item()

print(f"Accuracy on the train set: {(100 * correct / total):.2f}%")

# Testing loop
model.eval()
correct = 0
total = 0
loss_test_list = [] 
with torch.no_grad():
    for images, labels in test_loader:
        outputs = model(images)
        loss_test = criterion(outputs, labels).cpu().detach().numpy()
        loss_test_list.append(loss_test)
        _, predicted = torch.max(outputs.data, 1)
        total += labels.size(0)
        correct += (predicted == labels).sum().item()

print(f"Accuracy on the test set: {(100 * correct / total):.2f}%")

print(f"Loss on the train set: {np.mean(loss_train_list):.2f}")
print(f"Loss on the test set: {np.mean(loss_test_list):.2f}")
print("Generalization error:", np.mean(loss_test_list) - np.mean(loss_train_list))
# Out:
# Epoch [1/1], Step [100/300], Loss: 0.7110
# Epoch [1/1], Step [200/300], Loss: 0.5653
# Epoch [1/1], Step [300/300], Loss: 0.6209
# Accuracy on the train set: 80.30%
# Accuracy on the test set: 79.42%
# Loss on the train set: 0.54
# Loss on the test set: 0.57
# Generalization error: 0.023578882

# %%
### required qubits estimation ##############
# NN weights

numpy_weights = {}
nw_list = [] 
nw_list_normal = []
for name, param in model.state_dict().items():
    numpy_weights[name] = param.cpu().numpy()
for i in numpy_weights:
    nw_list.append(list(numpy_weights[i].flatten()))
for i in nw_list:
    for j in i:
        nw_list_normal.append(j)
print("# of NN parameters: ", len(nw_list_normal))
n_qubits = int(np.ceil(np.log2(len(nw_list_normal))))
print("Required qubit number: ", n_qubits)

n_qubit = n_qubits

#############################################
# Out:
# # of NN parameters:  6690
# Required qubit number:  13

# %%
### Some tool function definition ###########
def probs_to_weights(probs_):

    new_state_dict = {}
    data_iterator = probs_.view(-1)

    for name, param in CNNModel().state_dict().items():
        shape = param.shape
        num_elements = param.numel()
        chunk = data_iterator[:num_elements].reshape(shape)
        new_state_dict[name] = chunk
        data_iterator = data_iterator[num_elements:]
        
    return new_state_dict

def generate_qubit_states_torch(n_qubit):
    # Create a tensor of shape (2**n_qubit, n_qubit) with all possible combinations of 0 and 1
    all_states = torch.cartesian_prod(*[torch.tensor([-1, 1]) for _ in range(n_qubit)])
    return all_states

#############################################

### Main Learning-wise Hybridization model ##

class LewHybridNN(nn.Module):
    class QLayer(nn.Module):
        def __init__(self, n_blocks):
            super().__init__()
            self.n_wires = int(np.ceil(np.log2(len(nw_list_normal)))),
            self.n_wires = self.n_wires[0]
            self.n_blocks = n_blocks
            self.u3_layers = tq.QuantumModuleList()
            self.cu3_layers = tq.QuantumModuleList()
            # self.measure = tq.MeasureAll(tq.PauliZ)
            for _ in range(self.n_blocks):
                self.u3_layers.append(
                    tq.Op1QAllLayer(
                        op=tq.U3,
                        n_wires=self.n_wires,
                        has_params=True,
                        trainable=True,
                    )
                )
                self.cu3_layers.append(
                    tq.Op2QAllLayer(
                        op=tq.CU3,
                        n_wires=self.n_wires,
                        has_params=True,
                        trainable=True,
                        circular=True,
                    )
                )
                
        def forward(self):
            qdev = tq.QuantumDevice(
                n_wires=self.n_wires, bsz=1, device=next(self.parameters()).device
            )
            easy_scale_coeff = 2**(n_qubit-1)
            gamma = 0.1
            beta  = 0.8
            alpha = 0.3
            for k in range(self.n_blocks):
                self.u3_layers[k](qdev)
                self.cu3_layers[k](qdev)
                
            state_mag = qdev.get_states_1d().abs()[0] 
            state_mag = state_mag[:len(nw_list_normal)]
            x = torch.abs(state_mag) ** 2
            # x = torch.log(x)
            x = x.reshape(len(nw_list_normal),1)
            x = (beta*torch.tanh(gamma*easy_scale_coeff*x))**(alpha) 
            x = x - torch.mean(x)
            x.to(device)
            return x

        
        
    class MappingModel(nn.Module):
        def __init__(self, input_size, hidden_sizes, output_size):
            super().__init__()
            # Initialize layers: an input layer, multiple hidden layers, and an output layer
            self.input_layer = nn.Linear(input_size, hidden_sizes[0])
            self.hidden_layers = nn.ModuleList([nn.Linear(hidden_sizes[i], hidden_sizes[i+1]) for i in range(len(hidden_sizes)-1)])
            self.output_layer = nn.Linear(hidden_sizes[-1], output_size)
            
        def forward(self, X):
            # Ensure the input tensor is the same type as the weights
            X = X.type_as(self.input_layer.weight)

            # Input layer with ReLU activation
            X = self.input_layer(X)

            # Hidden layers with ReLU activation
            for hidden in self.hidden_layers:
                X = hidden(X)

            # Output layer with linear activation
            output = self.output_layer(X)
            # output = F.tanh(output)  # It's often better to use ReLU or similar; tanh is used here as it was in the original model.
            return output

    def __init__(self):
        """
        Definition of the *dressed* layout.
        """
        super().__init__()
        self.MappingNetwork = self.MappingModel(n_qubit+1, [4, 20, 4], 1).to(device)  
        # self.MappingNetwork = self.ConvMappingModel()
        self.QuantumNN = self.QLayer(q_depth).to(device)   #arch={"n_blocks": q_depth})
    
    def forward(self, x):
        """
        Defining how tensors are supposed to move through the *dressed* quantum
        net.
        """
        device = x.device

        probs_ = self.QuantumNN()
        probs_ = probs_[:len(nw_list_normal)]
        
        # Generate qubit states using PyTorch
        qubit_states_torch = generate_qubit_states_torch(n_qubit)[:len(nw_list_normal)]
        qubit_states_torch = qubit_states_torch.to(device)

        # Combine qubit states with probability values using PyTorch
        combined_data_torch = torch.cat((qubit_states_torch, probs_), dim=1)
        combined_data_torch = combined_data_torch.reshape(len(nw_list_normal), 1, n_qubit+1)
        
        prob_val_post_processed = self.MappingNetwork(combined_data_torch)
        prob_val_post_processed = prob_val_post_processed - prob_val_post_processed.mean()
        
        state_dict = probs_to_weights(prob_val_post_processed)

        ######## 
            
        dtype = torch.float32  # Ensure all tensors are of this type
        
        # Convolution layer 1 parameters
        conv1_weight = state_dict['conv1.weight'].to(device).type(dtype)
        conv1_bias = state_dict['conv1.bias'].to(device).type(dtype)

        # Convolution layer 2 parameters
        conv2_weight = state_dict['conv2.weight'].to(device).type(dtype)
        conv2_bias = state_dict['conv2.bias'].to(device).type(dtype)

        # Fully connected layer 1 parameters
        fc1_weight = state_dict['fc1.weight'].to(device).type(dtype)
        fc1_bias = state_dict['fc1.bias'].to(device).type(dtype)

        # Fully connected layer 2 parameters
        fc2_weight = state_dict['fc2.weight'].to(device).type(dtype)
        fc2_bias = state_dict['fc2.bias'].to(device).type(dtype)
        
        
        # Convolution 1
        x = F.conv2d(x, conv1_weight, conv1_bias, stride=1)
        x = F.max_pool2d(x, kernel_size=2, stride=2)

        # Convolution 2
        x = F.conv2d(x, conv2_weight, conv2_bias, stride=1)
        x = F.max_pool2d(x, kernel_size=2, stride=2)

        # Flatten
        x = x.view(x.size(0), -1)

        # Fully connected 1
        x = F.linear(x, fc1_weight, fc1_bias)

        # Fully connected 2
        x = F.linear(x, fc2_weight, fc2_bias)

    
        return x

# %%
### Training setting ########################

step = 1e-4                 # Learning rate
batch_size = 128       # Number of samples for each training step
num_epochs = 50             # Number of training epochs
q_depth = 16             # Depth of the quantum circuit (number of variational layers)
gamma_lr_scheduler = 0.1    # Learning rate reduction applied every 10 epochs.
q_delta = 0.1              # Initial spread of random quantum weights

train_dataset = datasets.FashionMNIST(root='./data', train=True, transform=transform, download=True)
train_loader = torch.utils.data.DataLoader(dataset=train_dataset, batch_size=batch_size, shuffle=True)

test_dataset = datasets.FashionMNIST(root='./data', train=False, transform=transform, download=True)
test_loader = torch.utils.data.DataLoader(dataset=test_dataset, batch_size=batch_size, shuffle=False)



# Instantiate the model, move it to GPU, and set up loss function and optimizer
model = LewHybridNN().to(device)
criterion = nn.CrossEntropyLoss()

optimizer = optim.Adam(model.parameters(), lr=step, weight_decay=1e-5, eps=1e-6)
scheduler = optim.lr_scheduler.ReduceLROnPlateau(optimizer, 'min', patience = 5, verbose = True, factor = 0.5)  # 'min' because we're minimizing loss

num_trainable_params_MM = sum(p.numel() for p in LewHybridNN.MappingModel(n_qubit+1,  [4, 20, 4], 1).parameters() if p.requires_grad)
# num_trainable_params_MM = sum(p.numel() for p in LewHybridNN.ConvMappingModel().parameters() if p.requires_grad)
num_trainable_params = sum(p.numel() for p in model.parameters() if p.requires_grad)
print("# of trainable parameter in Mapping model: ", num_trainable_params_MM)
print("# of trainable parameter in QNN model: ", num_trainable_params - num_trainable_params_MM)
print("# of trainable parameter in full model: ", num_trainable_params)
# Out:
# # of trainable parameter in Mapping model:  249
# # of trainable parameter in QNN model:  1248
# # of trainable parameter in full model:  1497

# %%
#############################################
### Training loop ###########################

### (Optional) Start from pretrained model ##
# model = torch.load('result_FF_mm_b1000_40_200_40/tq_mm_acc_70_bsf')
# model.eval()  # Set the model to evaluation mode
#############################################

loss_list = [] 
acc_list = [] 
acc_best = 0
for epoch in range(num_epochs):
    model.train()
    train_loss = 0
    for i, (images, labels) in enumerate(train_loader):
        correct = 0
        total = 0
        since_batch = time.time()
        
        images, labels = images.to(device), labels.to(device)  # Move data to GPU
        optimizer.zero_grad()
        # Forward pass
        outputs = model(images)
        # print("output: ", outputs)
        labels_one_hot = F.one_hot(labels, num_classes=10).float()
        _, predicted = torch.max(outputs.data, 1)
        total += labels.size(0)
        correct += (predicted == labels).sum().item()
        # Compute loss
        loss = criterion(outputs, labels_one_hot)
        # log_loss = torch.log(loss + 1e-6)
        
        loss_list.append(loss.cpu().detach().numpy())
        acc = 100 * correct / total
        acc_list.append(acc)
        train_loss += loss.cpu().detach().numpy()
        
        np.array(loss_list).dump("L16/loss_list.dat")
        np.array(acc_list).dump("L16/acc_list.dat")
        if acc > acc_best:
            torch.save(model, 'L16/tq_mm_acc_'+str(int(acc))+'_bsf')
            acc_best = acc
        # Backward pass and optimization
        loss.backward()
        
        optimizer.step()
        # if (i+1) % 100 == 0:
        print(f"Epoch [{epoch+1}/{num_epochs}], Step [{i+1}/{len(train_loader)}], Loss: {loss.item():.4f}, batch time: {time.time() - since_batch:.2f}, accuracy:  {(acc):.2f}%")
    
    train_loss /= len(train_loader)
    scheduler.step(train_loss) 
    
#############################################
# Out:
# Epoch [1/50], Step [1/469], Loss: 41.3161, batch time: 3.81, accuracy:  10.94%
# Epoch [1/50], Step [2/469], Loss: 38.6875, batch time: 0.82, accuracy:  11.72%
# Epoch [1/50], Step [3/469], Loss: 35.1488, batch time: 0.79, accuracy:  12.50%
# Epoch [1/50], Step [4/469], Loss: 32.8348, batch time: 0.81, accuracy:  18.75%
# Epoch [1/50], Step [5/469], Loss: 35.0093, batch time: 0.74, accuracy:  9.38%
# Epoch [1/50], Step [6/469], Loss: 30.1522, batch time: 0.79, accuracy:  15.62%
# Epoch [1/50], Step [7/469], Loss: 25.4352, batch time: 0.80, accuracy:  16.41%
# Epoch [1/50], Step [8/469], Loss: 29.7511, batch time: 0.82, accuracy:  14.84%
# Epoch [1/50], Step [9/469], Loss: 24.8017, batch time: 0.79, accuracy:  12.50%
# Epoch [1/50], Step [10/469], Loss: 29.6046, batch time: 0.78, accuracy:  8.59%
# Epoch [1/50], Step [11/469], Loss: 29.7837, batch time: 0.79, accuracy:  11.72%
# Epoch [1/50], Step [12/469], Loss: 24.4330, batch time: 0.91, accuracy:  11.72%
# Epoch [1/50], Step [13/469], Loss: 24.4856, batch time: 0.91, accuracy:  11.72%
# Epoch [1/50], Step [14/469], Loss: 24.2248, batch time: 0.95, accuracy:  16.41%
# Epoch [1/50], Step [15/469], Loss: 22.1301, batch time: 0.99, accuracy:  10.16%
# Epoch [1/50], Step [16/469], Loss: 20.1950, batch time: 0.92, accuracy:  17.19%
# Epoch [1/50], Step [17/469], Loss: 18.6193, batch time: 0.98, accuracy:  18.75%
# Epoch [1/50], Step [18/469], Loss: 20.2972, batch time: 0.94, accuracy:  9.38%
# Epoch [1/50], Step [19/469], Loss: 18.7737, batch time: 0.87, accuracy:  11.72%
# Epoch [1/50], Step [20/469], Loss: 18.6374, batch time: 0.74, accuracy:  9.38%
# Epoch [1/50], Step [21/469], Loss: 15.9395, batch time: 0.78, accuracy:  11.72%
# Epoch [1/50], Step [22/469], Loss: 18.9626, batch time: 0.80, accuracy:  12.50%
# Epoch [1/50], Step [23/469], Loss: 21.0387, batch time: 0.81, accuracy:  10.94%
# Epoch [1/50], Step [24/469], Loss: 17.8464, batch time: 0.81, accuracy:  16.41%
# Epoch [1/50], Step [25/469], Loss: 18.2078, batch time: 0.82, accuracy:  8.59%
# Epoch [1/50], Step [26/469], Loss: 15.6451, batch time: 0.77, accuracy:  16.41%
# Epoch [1/50], Step [27/469], Loss: 15.6621, batch time: 0.73, accuracy:  8.59%
# Epoch [1/50], Step [28/469], Loss: 15.0124, batch time: 0.79, accuracy:  19.53%
# Epoch [1/50], Step [29/469], Loss: 12.2913, batch time: 0.73, accuracy:  16.41%
# Epoch [1/50], Step [30/469], Loss: 13.3814, batch time: 0.72, accuracy:  14.84%
# Epoch [1/50], Step [31/469], Loss: 13.7006, batch time: 0.76, accuracy:  10.16%
# Epoch [1/50], Step [32/469], Loss: 12.5847, batch time: 0.80, accuracy:  11.72%
# Epoch [1/50], Step [33/469], Loss: 11.9744, batch time: 0.84, accuracy:  11.72%
# Epoch [1/50], Step [34/469], Loss: 11.5828, batch time: 0.84, accuracy:  16.41%
# Epoch [1/50], Step [35/469], Loss: 12.2226, batch time: 0.85, accuracy:  10.94%
# Epoch [1/50], Step [36/469], Loss: 12.6154, batch time: 0.92, accuracy:  7.81%
# Epoch [1/50], Step [37/469], Loss: 11.2647, batch time: 1.09, accuracy:  8.59%
# Epoch [1/50], Step [38/469], Loss: 11.5957, batch time: 0.99, accuracy:  14.84%
# Epoch [1/50], Step [39/469], Loss: 9.9296, batch time: 1.04, accuracy:  10.94%
# Epoch [1/50], Step [40/469], Loss: 9.8377, batch time: 0.99, accuracy:  14.06%
# Epoch [1/50], Step [41/469], Loss: 9.7510, batch time: 0.85, accuracy:  8.59%
# Epoch [1/50], Step [42/469], Loss: 7.8969, batch time: 0.71, accuracy:  12.50%
# Epoch [1/50], Step [43/469], Loss: 9.3631, batch time: 0.73, accuracy:  7.81%
# Epoch [1/50], Step [44/469], Loss: 7.5665, batch time: 0.74, accuracy:  14.84%
# Epoch [1/50], Step [45/469], Loss: 7.9624, batch time: 0.75, accuracy:  14.84%
# Epoch [1/50], Step [46/469], Loss: 7.6443, batch time: 0.75, accuracy:  14.84%
# Epoch [1/50], Step [47/469], Loss: 7.9747, batch time: 0.76, accuracy:  13.28%
# Epoch [1/50], Step [48/469], Loss: 8.1212, batch time: 0.74, accuracy:  11.72%
# Epoch [1/50], Step [49/469], Loss: 6.7626, batch time: 0.75, accuracy:  10.16%
# Epoch [1/50], Step [50/469], Loss: 7.7561, batch time: 0.72, accuracy:  11.72%
# Epoch [1/50], Step [51/469], Loss: 5.6853, batch time: 0.74, accuracy:  13.28%
# Epoch [1/50], Step [52/469], Loss: 6.9553, batch time: 0.72, accuracy:  10.94%
# Epoch [1/50], Step [53/469], Loss: 6.6325, batch time: 0.74, accuracy:  11.72%
# Epoch [1/50], Step [54/469], Loss: 6.7092, batch time: 0.73, accuracy:  10.16%
# Epoch [1/50], Step [55/469], Loss: 6.2807, batch time: 0.78, accuracy:  9.38%
# Epoch [1/50], Step [56/469], Loss: 6.0134, batch time: 0.78, accuracy:  10.16%
# Epoch [1/50], Step [57/469], Loss: 6.0390, batch time: 0.78, accuracy:  10.94%
# Epoch [1/50], Step [58/469], Loss: 6.1383, batch time: 0.88, accuracy:  13.28%
# Epoch [1/50], Step [59/469], Loss: 6.3446, batch time: 0.93, accuracy:  13.28%
# Epoch [1/50], Step [60/469], Loss: 6.1167, batch time: 0.91, accuracy:  10.94%
# Epoch [1/50], Step [61/469], Loss: 5.3121, batch time: 0.87, accuracy:  12.50%
# Epoch [1/50], Step [62/469], Loss: 5.7941, batch time: 0.73, accuracy:  10.94%
# Epoch [1/50], Step [63/469], Loss: 5.5086, batch time: 0.75, accuracy:  10.16%
# Epoch [1/50], Step [64/469], Loss: 5.8218, batch time: 0.73, accuracy:  8.59%
# Epoch [1/50], Step [65/469], Loss: 5.1402, batch time: 0.74, accuracy:  9.38%
# Epoch [1/50], Step [66/469], Loss: 5.3435, batch time: 0.74, accuracy:  10.94%
# Epoch [1/50], Step [67/469], Loss: 4.0010, batch time: 0.73, accuracy:  18.75%
# Epoch [1/50], Step [68/469], Loss: 4.7188, batch time: 0.73, accuracy:  8.59%
# Epoch [1/50], Step [69/469], Loss: 4.8507, batch time: 0.73, accuracy:  11.72%
# Epoch [1/50], Step [70/469], Loss: 4.3919, batch time: 0.74, accuracy:  10.16%
# Epoch [1/50], Step [71/469], Loss: 3.9810, batch time: 0.74, accuracy:  13.28%
# Epoch [1/50], Step [72/469], Loss: 4.5721, batch time: 0.76, accuracy:  8.59%
# Epoch [1/50], Step [73/469], Loss: 4.4333, batch time: 0.77, accuracy:  9.38%
# Epoch [1/50], Step [74/469], Loss: 4.4357, batch time: 0.72, accuracy:  10.94%
# Epoch [1/50], Step [75/469], Loss: 4.0445, batch time: 0.76, accuracy:  13.28%
# Epoch [1/50], Step [76/469], Loss: 3.9909, batch time: 0.79, accuracy:  14.06%
# Epoch [1/50], Step [77/469], Loss: 4.0815, batch time: 0.77, accuracy:  7.81%
# Epoch [1/50], Step [78/469], Loss: 3.5591, batch time: 0.88, accuracy:  8.59%
# Epoch [1/50], Step [79/469], Loss: 3.6838, batch time: 0.98, accuracy:  8.59%
# Epoch [1/50], Step [80/469], Loss: 3.8827, batch time: 0.94, accuracy:  7.03%
# Epoch [1/50], Step [81/469], Loss: 3.4441, batch time: 0.96, accuracy:  17.97%
# Epoch [1/50], Step [82/469], Loss: 3.7672, batch time: 0.97, accuracy:  10.94%
# Epoch [1/50], Step [83/469], Loss: 3.4543, batch time: 0.82, accuracy:  11.72%
# Epoch [1/50], Step [84/469], Loss: 3.6062, batch time: 0.71, accuracy:  11.72%
# Epoch [1/50], Step [85/469], Loss: 3.4337, batch time: 0.70, accuracy:  10.16%
# Epoch [1/50], Step [86/469], Loss: 3.2337, batch time: 0.70, accuracy:  9.38%
# Epoch [1/50], Step [87/469], Loss: 3.5735, batch time: 0.76, accuracy:  7.81%
# Epoch [1/50], Step [88/469], Loss: 3.3216, batch time: 0.73, accuracy:  11.72%
# Epoch [1/50], Step [89/469], Loss: 3.5643, batch time: 0.74, accuracy:  13.28%
# Epoch [1/50], Step [90/469], Loss: 3.2704, batch time: 0.73, accuracy:  7.03%
# Epoch [1/50], Step [91/469], Loss: 3.4461, batch time: 0.74, accuracy:  7.81%
# Epoch [1/50], Step [92/469], Loss: 3.5214, batch time: 0.74, accuracy:  7.81%
# Epoch [1/50], Step [93/469], Loss: 3.2036, batch time: 0.81, accuracy:  7.81%
# Epoch [1/50], Step [94/469], Loss: 3.2870, batch time: 0.76, accuracy:  10.16%
# Epoch [1/50], Step [95/469], Loss: 3.0752, batch time: 0.76, accuracy:  15.62%
# Epoch [1/50], Step [96/469], Loss: 3.2494, batch time: 0.76, accuracy:  10.94%
# Epoch [1/50], Step [97/469], Loss: 3.0821, batch time: 0.77, accuracy:  5.47%
# Epoch [1/50], Step [98/469], Loss: 3.1603, batch time: 0.80, accuracy:  14.06%
# Epoch [1/50], Step [99/469], Loss: 3.1586, batch time: 0.80, accuracy:  12.50%
# Epoch [1/50], Step [100/469], Loss: 2.9575, batch time: 0.92, accuracy:  10.94%
# Epoch [1/50], Step [101/469], Loss: 3.3246, batch time: 1.06, accuracy:  10.16%
# Epoch [1/50], Step [102/469], Loss: 3.1770, batch time: 1.05, accuracy:  6.25%
# Epoch [1/50], Step [103/469], Loss: 3.0032, batch time: 0.95, accuracy:  7.03%
# Epoch [1/50], Step [104/469], Loss: 2.9261, batch time: 0.94, accuracy:  14.84%
# Epoch [1/50], Step [105/469], Loss: 2.9256, batch time: 0.81, accuracy:  14.06%
# Epoch [1/50], Step [106/469], Loss: 2.9156, batch time: 0.77, accuracy:  15.62%
# Epoch [1/50], Step [107/469], Loss: 2.7031, batch time: 0.88, accuracy:  20.31%
# Epoch [1/50], Step [108/469], Loss: 2.8485, batch time: 0.72, accuracy:  16.41%
# Epoch [1/50], Step [109/469], Loss: 2.8154, batch time: 0.72, accuracy:  7.81%
# Epoch [1/50], Step [110/469], Loss: 3.0222, batch time: 0.76, accuracy:  8.59%
# Epoch [1/50], Step [111/469], Loss: 2.9477, batch time: 0.76, accuracy:  10.16%
# Epoch [1/50], Step [112/469], Loss: 2.7472, batch time: 0.74, accuracy:  13.28%
# Epoch [1/50], Step [113/469], Loss: 2.7815, batch time: 0.75, accuracy:  13.28%
# Epoch [1/50], Step [114/469], Loss: 2.8193, batch time: 0.75, accuracy:  13.28%
# Epoch [1/50], Step [115/469], Loss: 2.9148, batch time: 0.75, accuracy:  4.69%
# Epoch [1/50], Step [116/469], Loss: 2.7525, batch time: 0.75, accuracy:  16.41%
# Epoch [1/50], Step [117/469], Loss: 3.0107, batch time: 0.79, accuracy:  9.38%
# Epoch [1/50], Step [118/469], Loss: 2.8110, batch time: 0.77, accuracy:  10.94%
# Epoch [1/50], Step [119/469], Loss: 2.7484, batch time: 0.89, accuracy:  11.72%
# Epoch [1/50], Step [120/469], Loss: 2.7382, batch time: 0.87, accuracy:  9.38%
# Epoch [1/50], Step [121/469], Loss: 2.7062, batch time: 0.94, accuracy:  15.62%
# Epoch [1/50], Step [122/469], Loss: 2.6563, batch time: 1.02, accuracy:  8.59%
# Epoch [1/50], Step [123/469], Loss: 2.5958, batch time: 1.10, accuracy:  14.06%
# Epoch [1/50], Step [124/469], Loss: 2.9444, batch time: 0.96, accuracy:  8.59%
# Epoch [1/50], Step [125/469], Loss: 2.7340, batch time: 1.03, accuracy:  10.94%
# Epoch [1/50], Step [126/469], Loss: 2.6154, batch time: 1.00, accuracy:  15.62%
# Epoch [1/50], Step [127/469], Loss: 2.7935, batch time: 0.98, accuracy:  8.59%
# Epoch [1/50], Step [128/469], Loss: 2.7071, batch time: 0.80, accuracy:  14.06%
# Epoch [1/50], Step [129/469], Loss: 2.6612, batch time: 0.76, accuracy:  8.59%
# Epoch [1/50], Step [130/469], Loss: 2.7679, batch time: 0.77, accuracy:  11.72%
# Epoch [1/50], Step [131/469], Loss: 2.8033, batch time: 0.82, accuracy:  11.72%
# Epoch [1/50], Step [132/469], Loss: 2.6586, batch time: 0.81, accuracy:  17.19%
# Epoch [1/50], Step [133/469], Loss: 2.7130, batch time: 0.83, accuracy:  14.84%
# Epoch [1/50], Step [134/469], Loss: 2.5728, batch time: 0.80, accuracy:  10.94%
# Epoch [1/50], Step [135/469], Loss: 2.7539, batch time: 0.81, accuracy:  14.06%
# Epoch [1/50], Step [136/469], Loss: 2.5427, batch time: 0.80, accuracy:  18.75%
# Epoch [1/50], Step [137/469], Loss: 2.6102, batch time: 0.82, accuracy:  12.50%
# Epoch [1/50], Step [138/469], Loss: 2.6271, batch time: 0.80, accuracy:  8.59%
# Epoch [1/50], Step [139/469], Loss: 2.5931, batch time: 0.82, accuracy:  17.97%
# Epoch [1/50], Step [140/469], Loss: 2.5886, batch time: 0.87, accuracy:  18.75%
# Epoch [1/50], Step [141/469], Loss: 2.6298, batch time: 0.82, accuracy:  15.62%
# Epoch [1/50], Step [142/469], Loss: 2.5998, batch time: 0.87, accuracy:  10.94%
# Epoch [1/50], Step [143/469], Loss: 2.6123, batch time: 0.83, accuracy:  13.28%
# Epoch [1/50], Step [144/469], Loss: 2.3718, batch time: 0.99, accuracy:  24.22%
# Epoch [1/50], Step [145/469], Loss: 2.5564, batch time: 0.94, accuracy:  17.19%
# Epoch [1/50], Step [146/469], Loss: 2.5913, batch time: 1.06, accuracy:  15.62%
# Epoch [1/50], Step [147/469], Loss: 2.6598, batch time: 0.94, accuracy:  13.28%
# Epoch [1/50], Step [148/469], Loss: 2.5653, batch time: 0.95, accuracy:  10.94%
# Epoch [1/50], Step [149/469], Loss: 2.6900, batch time: 0.95, accuracy:  14.06%
# Epoch [1/50], Step [150/469], Loss: 2.5616, batch time: 0.93, accuracy:  18.75%
# Epoch [1/50], Step [151/469], Loss: 2.6576, batch time: 0.74, accuracy:  15.62%
# Epoch [1/50], Step [152/469], Loss: 2.6352, batch time: 0.70, accuracy:  14.84%
# Epoch [1/50], Step [153/469], Loss: 2.5603, batch time: 0.72, accuracy:  15.62%
# Epoch [1/50], Step [154/469], Loss: 2.6178, batch time: 0.72, accuracy:  12.50%
# Epoch [1/50], Step [155/469], Loss: 2.5783, batch time: 0.74, accuracy:  11.72%
# Epoch [1/50], Step [156/469], Loss: 2.6507, batch time: 0.74, accuracy:  9.38%
# Epoch [1/50], Step [157/469], Loss: 2.5564, batch time: 0.78, accuracy:  10.16%
# Epoch [1/50], Step [158/469], Loss: 2.7061, batch time: 0.78, accuracy:  10.94%
# Epoch [1/50], Step [159/469], Loss: 2.6787, batch time: 0.74, accuracy:  10.94%
# Epoch [1/50], Step [160/469], Loss: 2.6011, batch time: 0.74, accuracy:  14.06%
# Epoch [1/50], Step [161/469], Loss: 2.5971, batch time: 0.78, accuracy:  11.72%
# Epoch [1/50], Step [162/469], Loss: 2.5714, batch time: 0.80, accuracy:  13.28%
# Epoch [1/50], Step [163/469], Loss: 2.4855, batch time: 0.76, accuracy:  17.19%
# Epoch [1/50], Step [164/469], Loss: 2.6375, batch time: 0.79, accuracy:  9.38%
# Epoch [1/50], Step [165/469], Loss: 2.5268, batch time: 0.78, accuracy:  14.06%
# Epoch [1/50], Step [166/469], Loss: 2.5715, batch time: 0.83, accuracy:  17.97%
# Epoch [1/50], Step [167/469], Loss: 2.6560, batch time: 0.85, accuracy:  12.50%
# Epoch [1/50], Step [168/469], Loss: 2.6519, batch time: 0.90, accuracy:  9.38%
# Epoch [1/50], Step [169/469], Loss: 2.5566, batch time: 0.96, accuracy:  17.19%
# Epoch [1/50], Step [170/469], Loss: 2.4827, batch time: 0.96, accuracy:  17.97%
# Epoch [1/50], Step [171/469], Loss: 2.4792, batch time: 0.94, accuracy:  14.84%
# Epoch [1/50], Step [172/469], Loss: 2.6333, batch time: 0.90, accuracy:  8.59%
# Epoch [1/50], Step [173/469], Loss: 2.5297, batch time: 0.93, accuracy:  12.50%
# Epoch [1/50], Step [174/469], Loss: 2.5978, batch time: 0.94, accuracy:  7.03%
# Epoch [1/50], Step [175/469], Loss: 2.5138, batch time: 0.94, accuracy:  14.84%
# Epoch [1/50], Step [176/469], Loss: 2.6407, batch time: 0.94, accuracy:  11.72%
# Epoch [1/50], Step [177/469], Loss: 2.6697, batch time: 0.91, accuracy:  12.50%
# Epoch [1/50], Step [178/469], Loss: 2.5710, batch time: 0.93, accuracy:  14.06%
# Epoch [1/50], Step [179/469], Loss: 2.4963, batch time: 0.89, accuracy:  14.84%
# Epoch [1/50], Step [180/469], Loss: 2.4537, batch time: 0.91, accuracy:  16.41%
# Epoch [1/50], Step [181/469], Loss: 2.5252, batch time: 0.93, accuracy:  14.84%
# Epoch [1/50], Step [182/469], Loss: 2.5388, batch time: 0.84, accuracy:  14.84%
# Epoch [1/50], Step [183/469], Loss: 2.4556, batch time: 0.71, accuracy:  16.41%
# Epoch [1/50], Step [184/469], Loss: 2.5219, batch time: 0.71, accuracy:  10.94%
# Epoch [1/50], Step [185/469], Loss: 2.4114, batch time: 0.72, accuracy:  9.38%
# Epoch [1/50], Step [186/469], Loss: 2.4795, batch time: 0.74, accuracy:  11.72%
# Epoch [1/50], Step [187/469], Loss: 2.5479, batch time: 0.72, accuracy:  14.84%
# Epoch [1/50], Step [188/469], Loss: 2.5310, batch time: 0.72, accuracy:  9.38%
# Epoch [1/50], Step [189/469], Loss: 2.6027, batch time: 0.72, accuracy:  14.06%
# Epoch [1/50], Step [190/469], Loss: 2.5859, batch time: 0.72, accuracy:  14.06%
# Epoch [1/50], Step [191/469], Loss: 2.4725, batch time: 0.75, accuracy:  14.84%
# Epoch [1/50], Step [192/469], Loss: 2.5558, batch time: 0.73, accuracy:  12.50%
# Epoch [1/50], Step [193/469], Loss: 2.4509, batch time: 0.76, accuracy:  13.28%
# Epoch [1/50], Step [194/469], Loss: 2.5203, batch time: 0.73, accuracy:  11.72%
# Epoch [1/50], Step [195/469], Loss: 2.3878, batch time: 0.76, accuracy:  14.84%
# Epoch [1/50], Step [196/469], Loss: 2.5608, batch time: 0.77, accuracy:  14.06%
# Epoch [1/50], Step [197/469], Loss: 2.4323, batch time: 0.77, accuracy:  12.50%
# Epoch [1/50], Step [198/469], Loss: 2.4475, batch time: 0.78, accuracy:  17.97%
# Epoch [1/50], Step [199/469], Loss: 2.5627, batch time: 0.90, accuracy:  10.94%
# Epoch [1/50], Step [200/469], Loss: 2.4758, batch time: 0.91, accuracy:  14.84%
# Epoch [1/50], Step [201/469], Loss: 2.5516, batch time: 0.87, accuracy:  10.16%
# Epoch [1/50], Step [202/469], Loss: 2.4982, batch time: 0.71, accuracy:  11.72%
# Epoch [1/50], Step [203/469], Loss: 2.3531, batch time: 0.74, accuracy:  14.06%
# Epoch [1/50], Step [204/469], Loss: 2.4520, batch time: 0.73, accuracy:  16.41%
# Epoch [1/50], Step [205/469], Loss: 2.5640, batch time: 0.73, accuracy:  7.03%
# Epoch [1/50], Step [206/469], Loss: 2.5595, batch time: 0.76, accuracy:  10.16%
# Epoch [1/50], Step [207/469], Loss: 2.4984, batch time: 0.77, accuracy:  10.16%
# Epoch [1/50], Step [208/469], Loss: 2.5623, batch time: 0.77, accuracy:  9.38%
# Epoch [1/50], Step [209/469], Loss: 2.4181, batch time: 0.73, accuracy:  10.94%
# Epoch [1/50], Step [210/469], Loss: 2.4248, batch time: 0.75, accuracy:  14.84%
# Epoch [1/50], Step [211/469], Loss: 2.5222, batch time: 0.73, accuracy:  14.84%
# Epoch [1/50], Step [212/469], Loss: 2.3895, batch time: 0.75, accuracy:  11.72%
# Epoch [1/50], Step [213/469], Loss: 2.4732, batch time: 0.73, accuracy:  10.94%
# Epoch [1/50], Step [214/469], Loss: 2.5509, batch time: 0.76, accuracy:  7.81%
# Epoch [1/50], Step [215/469], Loss: 2.5295, batch time: 0.77, accuracy:  11.72%
# Epoch [1/50], Step [216/469], Loss: 2.5121, batch time: 0.80, accuracy:  10.94%
# Epoch [1/50], Step [217/469], Loss: 2.4947, batch time: 0.79, accuracy:  12.50%
# Epoch [1/50], Step [218/469], Loss: 2.4604, batch time: 0.80, accuracy:  14.84%
# Epoch [1/50], Step [219/469], Loss: 2.3794, batch time: 0.89, accuracy:  10.94%
# Epoch [1/50], Step [220/469], Loss: 2.4577, batch time: 1.02, accuracy:  14.06%
# Epoch [1/50], Step [221/469], Loss: 2.4349, batch time: 0.93, accuracy:  13.28%
# Epoch [1/50], Step [222/469], Loss: 2.5611, batch time: 0.94, accuracy:  5.47%
# Epoch [1/50], Step [223/469], Loss: 2.4014, batch time: 0.95, accuracy:  16.41%
# Epoch [1/50], Step [224/469], Loss: 2.4625, batch time: 0.93, accuracy:  10.16%
# Epoch [1/50], Step [225/469], Loss: 2.4179, batch time: 0.95, accuracy:  14.06%
# Epoch [1/50], Step [226/469], Loss: 2.4611, batch time: 0.93, accuracy:  18.75%
# Epoch [1/50], Step [227/469], Loss: 2.4190, batch time: 0.95, accuracy:  10.94%
# Epoch [1/50], Step [228/469], Loss: 2.4135, batch time: 0.85, accuracy:  14.84%
# Epoch [1/50], Step [229/469], Loss: 2.4738, batch time: 0.75, accuracy:  13.28%
# Epoch [1/50], Step [230/469], Loss: 2.4330, batch time: 0.77, accuracy:  11.72%
# Epoch [1/50], Step [231/469], Loss: 2.4734, batch time: 0.73, accuracy:  10.94%
# Epoch [1/50], Step [232/469], Loss: 2.5500, batch time: 0.76, accuracy:  15.62%
# Epoch [1/50], Step [233/469], Loss: 2.4674, batch time: 0.78, accuracy:  13.28%
# Epoch [1/50], Step [234/469], Loss: 2.4350, batch time: 0.72, accuracy:  14.06%
# Epoch [1/50], Step [235/469], Loss: 2.3746, batch time: 0.76, accuracy:  20.31%
# Epoch [1/50], Step [236/469], Loss: 2.3127, batch time: 0.76, accuracy:  16.41%
# Epoch [1/50], Step [237/469], Loss: 2.5625, batch time: 0.75, accuracy:  8.59%
# Epoch [1/50], Step [238/469], Loss: 2.4390, batch time: 0.76, accuracy:  14.06%
# Epoch [1/50], Step [239/469], Loss: 2.3896, batch time: 0.93, accuracy:  14.84%
# Epoch [1/50], Step [240/469], Loss: 2.5035, batch time: 0.84, accuracy:  8.59%
# Epoch [1/50], Step [241/469], Loss: 2.4396, batch time: 1.12, accuracy:  12.50%
# Epoch [1/50], Step [242/469], Loss: 2.4715, batch time: 1.05, accuracy:  10.94%
# Epoch [1/50], Step [243/469], Loss: 2.3847, batch time: 0.92, accuracy:  14.06%
# Epoch [1/50], Step [244/469], Loss: 2.4027, batch time: 1.09, accuracy:  21.09%
# Epoch [1/50], Step [245/469], Loss: 2.3926, batch time: 1.06, accuracy:  17.97%
# Epoch [1/50], Step [246/469], Loss: 2.4401, batch time: 1.43, accuracy:  14.06%
# Epoch [1/50], Step [247/469], Loss: 2.5651, batch time: 0.97, accuracy:  7.81%
# Epoch [1/50], Step [248/469], Loss: 2.2836, batch time: 0.80, accuracy:  18.75%
# Epoch [1/50], Step [249/469], Loss: 2.4795, batch time: 0.78, accuracy:  11.72%
# Epoch [1/50], Step [250/469], Loss: 2.4133, batch time: 0.76, accuracy:  15.62%
# Epoch [1/50], Step [251/469], Loss: 2.3569, batch time: 0.76, accuracy:  14.84%
# Epoch [1/50], Step [252/469], Loss: 2.3646, batch time: 0.72, accuracy:  14.84%
# Epoch [1/50], Step [253/469], Loss: 2.3837, batch time: 0.92, accuracy:  14.06%
# Epoch [1/50], Step [254/469], Loss: 2.5054, batch time: 0.89, accuracy:  13.28%
# Epoch [1/50], Step [255/469], Loss: 2.4803, batch time: 0.80, accuracy:  10.94%
# Epoch [1/50], Step [256/469], Loss: 2.5501, batch time: 0.74, accuracy:  11.72%
# Epoch [1/50], Step [257/469], Loss: 2.5058, batch time: 0.76, accuracy:  6.25%
# Epoch [1/50], Step [258/469], Loss: 2.4913, batch time: 0.74, accuracy:  9.38%
# Epoch [1/50], Step [259/469], Loss: 2.4191, batch time: 0.72, accuracy:  19.53%
# Epoch [1/50], Step [260/469], Loss: 2.4769, batch time: 0.77, accuracy:  9.38%
# Epoch [1/50], Step [261/469], Loss: 2.4058, batch time: 0.78, accuracy:  12.50%
# Epoch [1/50], Step [262/469], Loss: 2.4136, batch time: 0.91, accuracy:  12.50%
# Epoch [1/50], Step [263/469], Loss: 2.4956, batch time: 0.93, accuracy:  7.03%
# Epoch [1/50], Step [264/469], Loss: 2.4059, batch time: 0.94, accuracy:  18.75%
# Epoch [1/50], Step [265/469], Loss: 2.4403, batch time: 1.09, accuracy:  8.59%
# Epoch [1/50], Step [266/469], Loss: 2.4721, batch time: 1.49, accuracy:  7.81%
# Epoch [1/50], Step [267/469], Loss: 2.4273, batch time: 1.12, accuracy:  10.16%
# Epoch [1/50], Step [268/469], Loss: 2.4590, batch time: 0.85, accuracy:  12.50%
# Epoch [1/50], Step [269/469], Loss: 2.3083, batch time: 0.78, accuracy:  16.41%
# Epoch [1/50], Step [270/469], Loss: 2.4252, batch time: 0.88, accuracy:  13.28%
# Epoch [1/50], Step [271/469], Loss: 2.4387, batch time: 1.03, accuracy:  14.84%
# Epoch [1/50], Step [272/469], Loss: 2.4026, batch time: 0.91, accuracy:  10.16%
# Epoch [1/50], Step [273/469], Loss: 2.4409, batch time: 0.98, accuracy:  11.72%
# Epoch [1/50], Step [274/469], Loss: 2.3604, batch time: 0.81, accuracy:  16.41%
# Epoch [1/50], Step [275/469], Loss: 2.3823, batch time: 0.78, accuracy:  11.72%
# Epoch [1/50], Step [276/469], Loss: 2.4283, batch time: 0.76, accuracy:  13.28%
# Epoch [1/50], Step [277/469], Loss: 2.3294, batch time: 0.76, accuracy:  21.09%
# Epoch [1/50], Step [278/469], Loss: 2.4055, batch time: 0.75, accuracy:  10.16%
# Epoch [1/50], Step [279/469], Loss: 2.3858, batch time: 0.75, accuracy:  12.50%
# Epoch [1/50], Step [280/469], Loss: 2.3899, batch time: 0.78, accuracy:  12.50%
# Epoch [1/50], Step [281/469], Loss: 2.4225, batch time: 0.80, accuracy:  14.84%
# Epoch [1/50], Step [282/469], Loss: 2.4007, batch time: 0.77, accuracy:  13.28%
# Epoch [1/50], Step [283/469], Loss: 2.3614, batch time: 0.94, accuracy:  14.84%
# Epoch [1/50], Step [284/469], Loss: 2.3895, batch time: 1.16, accuracy:  11.72%
# Epoch [1/50], Step [285/469], Loss: 2.3952, batch time: 1.16, accuracy:  15.62%
# Epoch [1/50], Step [286/469], Loss: 2.4513, batch time: 1.06, accuracy:  11.72%
# Epoch [1/50], Step [287/469], Loss: 2.4027, batch time: 1.03, accuracy:  17.97%
# Epoch [1/50], Step [288/469], Loss: 2.3668, batch time: 0.82, accuracy:  13.28%
# Epoch [1/50], Step [289/469], Loss: 2.3675, batch time: 0.96, accuracy:  16.41%
# Epoch [1/50], Step [290/469], Loss: 2.4232, batch time: 0.86, accuracy:  15.62%
# Epoch [1/50], Step [291/469], Loss: 2.3986, batch time: 0.77, accuracy:  11.72%
# Epoch [1/50], Step [292/469], Loss: 2.4003, batch time: 0.83, accuracy:  14.06%
# Epoch [1/50], Step [293/469], Loss: 2.4578, batch time: 0.78, accuracy:  11.72%
# Epoch [1/50], Step [294/469], Loss: 2.3808, batch time: 0.87, accuracy:  12.50%
# Epoch [1/50], Step [295/469], Loss: 2.4408, batch time: 1.08, accuracy:  11.72%
# Epoch [1/50], Step [296/469], Loss: 2.4605, batch time: 0.80, accuracy:  10.16%
# Epoch [1/50], Step [297/469], Loss: 2.3495, batch time: 0.89, accuracy:  14.84%
# Epoch [1/50], Step [298/469], Loss: 2.3229, batch time: 0.94, accuracy:  17.97%
# Epoch [1/50], Step [299/469], Loss: 2.3720, batch time: 0.84, accuracy:  14.84%
# Epoch [1/50], Step [300/469], Loss: 2.3491, batch time: 1.20, accuracy:  18.75%
# Epoch [1/50], Step [301/469], Loss: 2.4333, batch time: 1.14, accuracy:  12.50%
# Epoch [1/50], Step [302/469], Loss: 2.3746, batch time: 1.02, accuracy:  14.06%
# Epoch [1/50], Step [303/469], Loss: 2.3726, batch time: 0.96, accuracy:  17.97%
# Epoch [1/50], Step [304/469], Loss: 2.4019, batch time: 0.94, accuracy:  13.28%
# Epoch [1/50], Step [305/469], Loss: 2.4216, batch time: 1.18, accuracy:  11.72%
# Epoch [1/50], Step [306/469], Loss: 2.4397, batch time: 1.08, accuracy:  9.38%
# Epoch [1/50], Step [307/469], Loss: 2.3407, batch time: 0.94, accuracy:  10.94%
# Epoch [1/50], Step [308/469], Loss: 2.4009, batch time: 0.86, accuracy:  12.50%
# Epoch [1/50], Step [309/469], Loss: 2.4159, batch time: 0.85, accuracy:  11.72%
# Epoch [1/50], Step [310/469], Loss: 2.4375, batch time: 0.85, accuracy:  14.06%
# Epoch [1/50], Step [311/469], Loss: 2.3986, batch time: 0.76, accuracy:  13.28%
# Epoch [1/50], Step [312/469], Loss: 2.4558, batch time: 0.89, accuracy:  10.16%
# Epoch [1/50], Step [313/469], Loss: 2.3510, batch time: 1.01, accuracy:  12.50%
# Epoch [1/50], Step [314/469], Loss: 2.3295, batch time: 0.87, accuracy:  11.72%
# Epoch [1/50], Step [315/469], Loss: 2.4190, batch time: 0.80, accuracy:  13.28%
# Epoch [1/50], Step [316/469], Loss: 2.3790, batch time: 0.87, accuracy:  14.06%
# Epoch [1/50], Step [317/469], Loss: 2.4246, batch time: 0.87, accuracy:  16.41%
# Epoch [1/50], Step [318/469], Loss: 2.3145, batch time: 0.86, accuracy:  14.06%
# Epoch [1/50], Step [319/469], Loss: 2.4328, batch time: 0.91, accuracy:  9.38%
# Epoch [1/50], Step [320/469], Loss: 2.3591, batch time: 0.84, accuracy:  14.06%
# Epoch [1/50], Step [321/469], Loss: 2.4515, batch time: 1.02, accuracy:  9.38%
# Epoch [1/50], Step [322/469], Loss: 2.4302, batch time: 0.94, accuracy:  7.03%
# Epoch [1/50], Step [323/469], Loss: 2.4077, batch time: 0.90, accuracy:  12.50%
# Epoch [1/50], Step [324/469], Loss: 2.3258, batch time: 1.16, accuracy:  16.41%
# Epoch [1/50], Step [325/469], Loss: 2.3212, batch time: 1.23, accuracy:  14.06%
# Epoch [1/50], Step [326/469], Loss: 2.3801, batch time: 1.04, accuracy:  12.50%
# Epoch [1/50], Step [327/469], Loss: 2.4521, batch time: 0.94, accuracy:  8.59%
# Epoch [1/50], Step [328/469], Loss: 2.3293, batch time: 1.10, accuracy:  13.28%
# Epoch [1/50], Step [329/469], Loss: 2.3568, batch time: 1.12, accuracy:  15.62%
# Epoch [1/50], Step [330/469], Loss: 2.3597, batch time: 1.00, accuracy:  12.50%
# Epoch [1/50], Step [331/469], Loss: 2.3337, batch time: 0.81, accuracy:  14.84%
# Epoch [1/50], Step [332/469], Loss: 2.4522, batch time: 0.96, accuracy:  11.72%
# Epoch [1/50], Step [333/469], Loss: 2.4015, batch time: 0.82, accuracy:  10.16%
# Epoch [1/50], Step [334/469], Loss: 2.3287, batch time: 0.80, accuracy:  15.62%
# Epoch [1/50], Step [335/469], Loss: 2.3192, batch time: 0.95, accuracy:  17.19%
# Epoch [1/50], Step [336/469], Loss: 2.3239, batch time: 0.77, accuracy:  10.94%
# Epoch [1/50], Step [337/469], Loss: 2.4061, batch time: 0.80, accuracy:  11.72%
# Epoch [1/50], Step [338/469], Loss: 2.3571, batch time: 1.09, accuracy:  10.94%
# Epoch [1/50], Step [339/469], Loss: 2.4327, batch time: 0.87, accuracy:  10.16%
# Epoch [1/50], Step [340/469], Loss: 2.3437, batch time: 0.76, accuracy:  13.28%
# Epoch [1/50], Step [341/469], Loss: 2.3872, batch time: 1.01, accuracy:  14.06%
# Epoch [1/50], Step [342/469], Loss: 2.3897, batch time: 1.09, accuracy:  10.16%
# Epoch [1/50], Step [343/469], Loss: 2.3479, batch time: 1.18, accuracy:  8.59%
# Epoch [1/50], Step [344/469], Loss: 2.4072, batch time: 1.17, accuracy:  10.94%
# Epoch [1/50], Step [345/469], Loss: 2.3528, batch time: 1.03, accuracy:  9.38%
# Epoch [1/50], Step [346/469], Loss: 2.4022, batch time: 1.00, accuracy:  11.72%
# Epoch [1/50], Step [347/469], Loss: 2.3322, batch time: 1.03, accuracy:  17.97%
# Epoch [1/50], Step [348/469], Loss: 2.3692, batch time: 0.75, accuracy:  10.16%
# Epoch [1/50], Step [349/469], Loss: 2.4224, batch time: 0.76, accuracy:  11.72%
# Epoch [1/50], Step [350/469], Loss: 2.3807, batch time: 0.72, accuracy:  12.50%
# Epoch [1/50], Step [351/469], Loss: 2.4009, batch time: 0.97, accuracy:  14.06%
# Epoch [1/50], Step [352/469], Loss: 2.3552, batch time: 0.89, accuracy:  12.50%
# Epoch [1/50], Step [353/469], Loss: 2.4728, batch time: 0.74, accuracy:  8.59%
# Epoch [1/50], Step [354/469], Loss: 2.3629, batch time: 0.74, accuracy:  14.06%
# Epoch [1/50], Step [355/469], Loss: 2.3312, batch time: 0.99, accuracy:  19.53%
# Epoch [1/50], Step [356/469], Loss: 2.3723, batch time: 0.76, accuracy:  15.62%
# Epoch [1/50], Step [357/469], Loss: 2.3952, batch time: 0.73, accuracy:  8.59%
# Epoch [1/50], Step [358/469], Loss: 2.3874, batch time: 0.85, accuracy:  12.50%
# Epoch [1/50], Step [359/469], Loss: 2.3586, batch time: 0.80, accuracy:  15.62%
# Epoch [1/50], Step [360/469], Loss: 2.3892, batch time: 0.78, accuracy:  14.84%
# Epoch [1/50], Step [361/469], Loss: 2.4426, batch time: 0.78, accuracy:  5.47%
# Epoch [1/50], Step [362/469], Loss: 2.4057, batch time: 0.81, accuracy:  14.84%
# Epoch [1/50], Step [363/469], Loss: 2.3430, batch time: 0.93, accuracy:  14.84%
# Epoch [1/50], Step [364/469], Loss: 2.3091, batch time: 1.37, accuracy:  16.41%
# Epoch [1/50], Step [365/469], Loss: 2.3227, batch time: 1.12, accuracy:  15.62%
# Epoch [1/50], Step [366/469], Loss: 2.4102, batch time: 0.98, accuracy:  11.72%
# Epoch [1/50], Step [367/469], Loss: 2.3740, batch time: 1.19, accuracy:  6.25%
# Epoch [1/50], Step [368/469], Loss: 2.3078, batch time: 1.01, accuracy:  15.62%
# Epoch [1/50], Step [369/469], Loss: 2.4159, batch time: 0.92, accuracy:  8.59%
# Epoch [1/50], Step [370/469], Loss: 2.3211, batch time: 0.83, accuracy:  16.41%
# Epoch [1/50], Step [371/469], Loss: 2.3699, batch time: 0.78, accuracy:  11.72%
# Epoch [1/50], Step [372/469], Loss: 2.2894, batch time: 0.76, accuracy:  16.41%
# Epoch [1/50], Step [373/469], Loss: 2.3630, batch time: 0.78, accuracy:  13.28%
# Epoch [1/50], Step [374/469], Loss: 2.3953, batch time: 0.79, accuracy:  7.81%
# Epoch [1/50], Step [375/469], Loss: 2.3729, batch time: 0.80, accuracy:  13.28%
# Epoch [1/50], Step [376/469], Loss: 2.3314, batch time: 0.88, accuracy:  12.50%
# Epoch [1/50], Step [377/469], Loss: 2.4131, batch time: 1.15, accuracy:  10.16%
# Epoch [1/50], Step [378/469], Loss: 2.3873, batch time: 1.16, accuracy:  8.59%
# Epoch [1/50], Step [379/469], Loss: 2.3278, batch time: 0.92, accuracy:  13.28%
# Epoch [1/50], Step [380/469], Loss: 2.3694, batch time: 1.05, accuracy:  13.28%
# Epoch [1/50], Step [381/469], Loss: 2.3611, batch time: 0.89, accuracy:  13.28%
# Epoch [1/50], Step [382/469], Loss: 2.2754, batch time: 1.12, accuracy:  17.19%
# Epoch [1/50], Step [383/469], Loss: 2.3597, batch time: 0.97, accuracy:  11.72%
# Epoch [1/50], Step [384/469], Loss: 2.3043, batch time: 1.17, accuracy:  13.28%
# Epoch [1/50], Step [385/469], Loss: 2.3809, batch time: 1.00, accuracy:  7.03%
# Epoch [1/50], Step [386/469], Loss: 2.3853, batch time: 0.91, accuracy:  13.28%
# Epoch [1/50], Step [387/469], Loss: 2.3754, batch time: 1.20, accuracy:  10.94%
# Epoch [1/50], Step [388/469], Loss: 2.3659, batch time: 0.93, accuracy:  9.38%
# Epoch [1/50], Step [389/469], Loss: 2.3392, batch time: 0.73, accuracy:  17.19%
# Epoch [1/50], Step [390/469], Loss: 2.3250, batch time: 0.81, accuracy:  15.62%
# Epoch [1/50], Step [391/469], Loss: 2.3777, batch time: 0.84, accuracy:  9.38%
# Epoch [1/50], Step [392/469], Loss: 2.3550, batch time: 0.78, accuracy:  18.75%
# Epoch [1/50], Step [393/469], Loss: 2.3627, batch time: 0.74, accuracy:  7.81%
# Epoch [1/50], Step [394/469], Loss: 2.3826, batch time: 0.83, accuracy:  13.28%
# Epoch [1/50], Step [395/469], Loss: 2.3418, batch time: 0.75, accuracy:  13.28%
# Epoch [1/50], Step [396/469], Loss: 2.3609, batch time: 0.81, accuracy:  12.50%
# Epoch [1/50], Step [397/469], Loss: 2.3842, batch time: 0.85, accuracy:  14.84%
# Epoch [1/50], Step [398/469], Loss: 2.3915, batch time: 0.91, accuracy:  16.41%
# Epoch [1/50], Step [399/469], Loss: 2.3893, batch time: 0.84, accuracy:  12.50%
# Epoch [1/50], Step [400/469], Loss: 2.3632, batch time: 1.12, accuracy:  11.72%
# Epoch [1/50], Step [401/469], Loss: 2.3549, batch time: 1.04, accuracy:  11.72%
# Epoch [1/50], Step [402/469], Loss: 2.3286, batch time: 1.05, accuracy:  13.28%
# Epoch [1/50], Step [403/469], Loss: 2.3398, batch time: 0.95, accuracy:  17.97%
# Epoch [1/50], Step [404/469], Loss: 2.4009, batch time: 1.02, accuracy:  11.72%
# Epoch [1/50], Step [405/469], Loss: 2.3450, batch time: 1.00, accuracy:  17.19%
# Epoch [1/50], Step [406/469], Loss: 2.3167, batch time: 0.95, accuracy:  19.53%
# Epoch [1/50], Step [407/469], Loss: 2.3724, batch time: 0.72, accuracy:  9.38%
# Epoch [1/50], Step [408/469], Loss: 2.3588, batch time: 0.81, accuracy:  10.94%
# Epoch [1/50], Step [409/469], Loss: 2.3601, batch time: 0.78, accuracy:  12.50%
# Epoch [1/50], Step [410/469], Loss: 2.3786, batch time: 0.84, accuracy:  8.59%
# Epoch [1/50], Step [411/469], Loss: 2.3048, batch time: 0.89, accuracy:  12.50%
# Epoch [1/50], Step [412/469], Loss: 2.3822, batch time: 0.87, accuracy:  13.28%
# Epoch [1/50], Step [413/469], Loss: 2.3448, batch time: 0.90, accuracy:  11.72%
# Epoch [1/50], Step [414/469], Loss: 2.3434, batch time: 1.06, accuracy:  14.84%
# Epoch [1/50], Step [415/469], Loss: 2.3235, batch time: 0.87, accuracy:  9.38%
# Epoch [1/50], Step [416/469], Loss: 2.2546, batch time: 0.91, accuracy:  20.31%
# Epoch [1/50], Step [417/469], Loss: 2.3486, batch time: 0.96, accuracy:  10.94%
# Epoch [1/50], Step [418/469], Loss: 2.3147, batch time: 0.79, accuracy:  16.41%
# Epoch [1/50], Step [419/469], Loss: 2.3293, batch time: 0.87, accuracy:  15.62%
# Epoch [1/50], Step [420/469], Loss: 2.3317, batch time: 0.89, accuracy:  14.06%
# Epoch [1/50], Step [421/469], Loss: 2.3899, batch time: 1.00, accuracy:  8.59%
# Epoch [1/50], Step [422/469], Loss: 2.3658, batch time: 1.02, accuracy:  11.72%
# Epoch [1/50], Step [423/469], Loss: 2.3744, batch time: 1.06, accuracy:  9.38%
# Epoch [1/50], Step [424/469], Loss: 2.3042, batch time: 1.07, accuracy:  15.62%
# Epoch [1/50], Step [425/469], Loss: 2.3807, batch time: 0.80, accuracy:  7.81%
# Epoch [1/50], Step [426/469], Loss: 2.3484, batch time: 0.70, accuracy:  9.38%
# Epoch [1/50], Step [427/469], Loss: 2.3127, batch time: 0.80, accuracy:  14.06%
# Epoch [1/50], Step [428/469], Loss: 2.3741, batch time: 0.75, accuracy:  10.94%
# Epoch [1/50], Step [429/469], Loss: 2.3115, batch time: 0.91, accuracy:  10.94%
# Epoch [1/50], Step [430/469], Loss: 2.3267, batch time: 0.96, accuracy:  13.28%
# Epoch [1/50], Step [431/469], Loss: 2.3047, batch time: 0.97, accuracy:  13.28%
# Epoch [1/50], Step [432/469], Loss: 2.3413, batch time: 0.83, accuracy:  14.06%
# Epoch [1/50], Step [433/469], Loss: 2.3221, batch time: 0.83, accuracy:  17.19%
# Epoch [1/50], Step [434/469], Loss: 2.2671, batch time: 0.76, accuracy:  15.62%
# Epoch [1/50], Step [435/469], Loss: 2.2973, batch time: 0.69, accuracy:  18.75%
# Epoch [1/50], Step [436/469], Loss: 2.3437, batch time: 0.79, accuracy:  10.16%
# Epoch [1/50], Step [437/469], Loss: 2.3608, batch time: 0.78, accuracy:  13.28%
# Epoch [1/50], Step [438/469], Loss: 2.3136, batch time: 0.91, accuracy:  13.28%
# Epoch [1/50], Step [439/469], Loss: 2.3527, batch time: 0.85, accuracy:  14.06%
# Epoch [1/50], Step [440/469], Loss: 2.3742, batch time: 0.96, accuracy:  9.38%
# Epoch [1/50], Step [441/469], Loss: 2.3533, batch time: 1.25, accuracy:  10.16%
# Epoch [1/50], Step [442/469], Loss: 2.3382, batch time: 0.91, accuracy:  14.06%
# Epoch [1/50], Step [443/469], Loss: 2.3615, batch time: 1.00, accuracy:  17.19%
# Epoch [1/50], Step [444/469], Loss: 2.3683, batch time: 0.90, accuracy:  13.28%
# Epoch [1/50], Step [445/469], Loss: 2.3786, batch time: 0.97, accuracy:  7.81%
# Epoch [1/50], Step [446/469], Loss: 2.2962, batch time: 0.98, accuracy:  17.19%
# Epoch [1/50], Step [447/469], Loss: 2.3885, batch time: 1.17, accuracy:  9.38%
# Epoch [1/50], Step [448/469], Loss: 2.3506, batch time: 1.09, accuracy:  14.06%
# Epoch [1/50], Step [449/469], Loss: 2.2374, batch time: 1.10, accuracy:  17.97%
# Epoch [1/50], Step [450/469], Loss: 2.3507, batch time: 0.87, accuracy:  11.72%
# Epoch [1/50], Step [451/469], Loss: 2.3294, batch time: 0.95, accuracy:  11.72%
# Epoch [1/50], Step [452/469], Loss: 2.2787, batch time: 0.81, accuracy:  16.41%
# Epoch [1/50], Step [453/469], Loss: 2.3507, batch time: 1.01, accuracy:  14.06%
# Epoch [1/50], Step [454/469], Loss: 2.3634, batch time: 0.94, accuracy:  10.16%
# Epoch [1/50], Step [455/469], Loss: 2.3128, batch time: 0.82, accuracy:  17.19%
# Epoch [1/50], Step [456/469], Loss: 2.3143, batch time: 0.78, accuracy:  14.84%
# Epoch [1/50], Step [457/469], Loss: 2.3103, batch time: 0.85, accuracy:  9.38%
# Epoch [1/50], Step [458/469], Loss: 2.3362, batch time: 1.10, accuracy:  15.62%
# Epoch [1/50], Step [459/469], Loss: 2.3037, batch time: 1.07, accuracy:  16.41%
# Epoch [1/50], Step [460/469], Loss: 2.3193, batch time: 1.04, accuracy:  12.50%
# Epoch [1/50], Step [461/469], Loss: 2.3783, batch time: 1.06, accuracy:  10.16%
# Epoch [1/50], Step [462/469], Loss: 2.3378, batch time: 0.96, accuracy:  12.50%
# Epoch [1/50], Step [463/469], Loss: 2.3666, batch time: 0.89, accuracy:  10.94%
# Epoch [1/50], Step [464/469], Loss: 2.3294, batch time: 0.82, accuracy:  12.50%
# Epoch [1/50], Step [465/469], Loss: 2.3107, batch time: 1.21, accuracy:  14.06%
# Epoch [1/50], Step [466/469], Loss: 2.3174, batch time: 1.20, accuracy:  10.94%
# Epoch [1/50], Step [467/469], Loss: 2.3050, batch time: 1.02, accuracy:  7.81%
# Epoch [1/50], Step [468/469], Loss: 2.3381, batch time: 1.34, accuracy:  11.72%
# Epoch [1/50], Step [469/469], Loss: 2.3359, batch time: 1.20, accuracy:  9.38%
# Epoch [2/50], Step [1/469], Loss: 2.3585, batch time: 1.10, accuracy:  12.50%
# Epoch [2/50], Step [2/469], Loss: 2.3143, batch time: 1.18, accuracy:  14.84%
# Epoch [2/50], Step [3/469], Loss: 2.3682, batch time: 0.86, accuracy:  9.38%
# Epoch [2/50], Step [4/469], Loss: 2.3236, batch time: 0.85, accuracy:  13.28%
# Epoch [2/50], Step [5/469], Loss: 2.3209, batch time: 0.74, accuracy:  14.06%
# Epoch [2/50], Step [6/469], Loss: 2.2881, batch time: 0.76, accuracy:  15.62%
# Epoch [2/50], Step [7/469], Loss: 2.3219, batch time: 0.74, accuracy:  10.94%
# Epoch [2/50], Step [8/469], Loss: 2.3525, batch time: 0.73, accuracy:  11.72%
# Epoch [2/50], Step [9/469], Loss: 2.3843, batch time: 0.75, accuracy:  10.94%
# Epoch [2/50], Step [10/469], Loss: 2.3378, batch time: 0.89, accuracy:  14.06%
# Epoch [2/50], Step [11/469], Loss: 2.3382, batch time: 0.75, accuracy:  12.50%
# Epoch [2/50], Step [12/469], Loss: 2.3212, batch time: 0.90, accuracy:  14.06%
# Epoch [2/50], Step [13/469], Loss: 2.3058, batch time: 1.08, accuracy:  14.84%
# Epoch [2/50], Step [14/469], Loss: 2.3641, batch time: 0.86, accuracy:  14.84%
# Epoch [2/50], Step [15/469], Loss: 2.3340, batch time: 0.78, accuracy:  14.06%
batch time: 0.42, accuracy:  78.91%
# Epoch [50/50], Step [437/469], Loss: 0.5099, batch time: 0.42, accuracy:  85.94%
# Epoch [50/50], Step [438/469], Loss: 0.5267, batch time: 0.41, accuracy:  80.47%
# Epoch [50/50], Step [439/469], Loss: 0.6398, batch time: 0.41, accuracy:  74.22%
# Epoch [50/50], Step [440/469], Loss: 0.4498, batch time: 0.41, accuracy:  85.16%
# Epoch [50/50], Step [441/469], Loss: 0.5956, batch time: 0.42, accuracy:  73.44%
# Epoch [50/50], Step [442/469], Loss: 0.6387, batch time: 0.42, accuracy:  75.00%
# Epoch [50/50], Step [443/469], Loss: 0.6515, batch time: 0.41, accuracy:  75.00%
# Epoch [50/50], Step [444/469], Loss: 0.5842, batch time: 0.42, accuracy:  78.91%
# Epoch [50/50], Step [445/469], Loss: 0.5537, batch time: 0.42, accuracy:  81.25%
# Epoch [50/50], Step [446/469], Loss: 0.5734, batch time: 0.41, accuracy:  83.59%
# Epoch [50/50], Step [447/469], Loss: 0.5668, batch time: 0.42, accuracy:  78.12%
# Epoch [50/50], Step [448/469], Loss: 0.6779, batch time: 0.42, accuracy:  77.34%
# Epoch [50/50], Step [449/469], Loss: 0.9088, batch time: 0.41, accuracy:  71.88%
# Epoch [50/50], Step [450/469], Loss: 0.5853, batch time: 0.42, accuracy:  80.47%
# Epoch [50/50], Step [451/469], Loss: 0.5674, batch time: 0.42, accuracy:  78.91%
# Epoch [50/50], Step [452/469], Loss: 0.5730, batch time: 0.41, accuracy:  79.69%
# Epoch [50/50], Step [453/469], Loss: 0.6292, batch time: 0.41, accuracy:  78.91%
# Epoch [50/50], Step [454/469], Loss: 0.4823, batch time: 0.41, accuracy:  83.59%
# Epoch [50/50], Step [455/469], Loss: 0.6146, batch time: 0.42, accuracy:  75.78%
# Epoch [50/50], Step [456/469], Loss: 0.5743, batch time: 0.41, accuracy:  76.56%
# Epoch [50/50], Step [457/469], Loss: 0.5989, batch time: 0.42, accuracy:  78.91%
# Epoch [50/50], Step [458/469], Loss: 0.5464, batch time: 0.41, accuracy:  78.91%
# Epoch [50/50], Step [459/469], Loss: 0.6081, batch time: 0.41, accuracy:  78.91%
# Epoch [50/50], Step [460/469], Loss: 0.5540, batch time: 0.42, accuracy:  82.81%
# Epoch [50/50], Step [461/469], Loss: 0.4317, batch time: 0.41, accuracy:  85.16%
# Epoch [50/50], Step [462/469], Loss: 0.5235, batch time: 0.42, accuracy:  82.03%
# Epoch [50/50], Step [463/469], Loss: 0.4641, batch time: 0.41, accuracy:  83.59%
# Epoch [50/50], Step [464/469], Loss: 0.6416, batch time: 0.42, accuracy:  74.22%
# Epoch [50/50], Step [465/469], Loss: 0.5027, batch time: 0.42, accuracy:  80.47%
# Epoch [50/50], Step [466/469], Loss: 0.4967, batch time: 0.41, accuracy:  79.69%
# Epoch [50/50], Step [467/469], Loss: 0.6110, batch time: 0.41, accuracy:  73.44%
# Epoch [50/50], Step [468/469], Loss: 0.6286, batch time: 0.41, accuracy:  76.56%
# Epoch [50/50], Step [469/469], Loss: 0.4856, batch time: 0.42, accuracy:  82.29%

# %%
# Testing train loop
model.eval()
correct = 0
total = 0
loss_train_list = []
with torch.no_grad():
    for images, labels in train_loader:
        images, labels = images.to(device), labels.to(device)  # Move data to GPU
        outputs = model(images)
        loss_train = criterion(outputs, labels).cpu().detach().numpy()
        loss_train_list.append(loss_train)
        _, predicted = torch.max(outputs.data, 1)
        total += labels.size(0)
        correct += (predicted == labels).sum().item()

print(f"Accuracy on the train set: {(100 * correct / total):.2f}%")
print(f"Loss on the train set: {np.mean(loss_train_list):.2f}")

# Testing loop
model.eval()
correct = 0
total = 0
loss_test_list = []

with torch.no_grad():
    for images, labels in test_loader:
        images, labels = images.to(device), labels.to(device)  # Move data to GPU
        outputs = model(images)
        loss_test = criterion(outputs, labels).cpu().detach().numpy()
        loss_test_list.append(loss_test)

        _, predicted = torch.max(outputs.data, 1)
        total += labels.size(0)
        correct += (predicted == labels).sum().item()

print(f"Accuracy on the test set: {(100 * correct / total):.2f}%")
print(f"Loss on the test set: {np.mean(loss_test_list):.2f}")

print("Generalization error:", np.mean(loss_test_list) - np.mean(loss_train_list))
# Out:
# Accuracy on the train set: 79.46%
# Loss on the train set: 0.57
# Accuracy on the test set: 78.71%
# Loss on the test set: 0.59
# Generalization error: 0.020973265
