# %%
# import code block 

import torch
from torch.utils.data import Dataset, DataLoader, Subset
import torch.nn as nn
import torch.nn.functional as F
import torch.optim as optim
import torch
import pennylane as qml
from pennylane import numpy as np
import matplotlib.pyplot as plt
import time 

import torchquantum as tq
 
# import quantum_datasets as qd

# %%
Ising_chain_data_set = qml.data.load("qspin", sysname="Ising", periodicity="full", lattice="chain", layout=["1x16", "1x8", "1x4"])

# %%
# Determine the max length for padding
max_length_meas = max([len(item.shadow_meas[0][0]) for item in Ising_chain_data_set])
max_length_basis = max([len(item.shadow_basis[0][0]) for item in Ising_chain_data_set])
max_length = max(max_length_meas, max_length_basis)

dataset_shadow_meas_and_basis = []
for i, item in enumerate(Ising_chain_data_set):
    for h_value in range(100):
        for slice_ in range(40):
            sample_per_slice = 25
            meas = torch.tensor(item.shadow_meas[h_value][sample_per_slice*slice_:sample_per_slice*(slice_+1)])
            basis = torch.tensor(item.shadow_basis[h_value][sample_per_slice*slice_:sample_per_slice*(slice_+1)])

            # Pad sequences to max_length
            meas_padded = torch.nn.functional.pad(meas, (0, max_length - meas.size(1)), value=0)  # Pad at the end
            basis_padded = torch.nn.functional.pad(basis, (0, max_length - basis.size(1)), value=0)  # Pad at the end
            spin_num = 2 ** (4 - i % 3)
            if i < 3:
                periodicity = 0 ## represent open periodicity
            else:
                periodicity = 1 ## represent close periodicity

            spin_num_tensor = torch.full((sample_per_slice, 1), spin_num).float()
            periodicity_tensor = torch.full((sample_per_slice, 1), periodicity).float()

            combined = torch.cat(
                (   
                    spin_num_tensor,
                    periodicity_tensor,
                    meas_padded,
                    basis_padded,
                    # torch.full((sample_per_slice,), item.parameters['h'][h_value]).unsqueeze(1)  # Uncomment if including h
                ),
                dim=1).unsqueeze(0).float()

            dataset_shadow_meas_and_basis.append(combined)

# %%
## Construct the label data, here we use the phase label as the target of the classifcation task. 

dataset_order_parameter = [] 
for h_value_index in range(100):
    for slice_ in range(40):
        dataset_order_parameter.append(
            #torch.tensor(Ising_chain_data_set[0].parameters['h'][h_value_index]).float()
            torch.tensor((1/8)*Ising_chain_data_set[0].order_params[h_value_index]).float()
        )
        
dataset_phase_label = []
for data in Ising_chain_data_set:
    for h_value_index in range(100):
        for slice_ in range(40):
            h = data.parameters['h'][h_value_index]
            if h < 1:
                dataset_phase_label.append(0)
            elif h >= 1:
                dataset_phase_label.append(1)

# %%
## A function to generate the dataset that will be recognized by Pytorch

class MatrixDataset(Dataset):
    """Matrix and label dataset."""

    def __init__(self, matrices, labels):
        """
        Args:
            matrices (list of numpy.ndarray or torch.Tensor): List of matrices.
            labels (list of int): List of labels corresponding to each matrix.
        """
        self.matrices = matrices
        self.labels = labels

    def __len__(self):
        return len(self.matrices)

    def __getitem__(self, idx):
        matrix = self.matrices[idx]
        label = self.labels[idx]

        # Convert to torch.Tensor if not already
        if not isinstance(matrix, torch.Tensor):
            matrix = torch.tensor(matrix, dtype=torch.float32)

        if not isinstance(label, torch.Tensor):
            label = torch.tensor(label, dtype=torch.long)

        return matrix, label

# %%
# dataset = MatrixDataset(dataset_shadow_meas_and_basis, dataset_order_parameter)
dataset = MatrixDataset(dataset_shadow_meas_and_basis, dataset_phase_label)

## split the data for testing and training 

# Assuming 'dataset' is your initialized dataset
dataset_size = len(dataset)
train_size = int(0.8 * dataset_size)  # 80% for training
test_size = dataset_size - train_size  # 20% for testing

# Calculate the interval for selecting test indices in the interleaved pattern
# The +1 ensures that we round up, preventing the train set from being too small
interval = int(dataset_size / test_size) + 1

train_indices = []
test_indices = []

for i in range(dataset_size):
    if i % interval == 0:
        test_indices.append(i)
    else:
        train_indices.append(i)

# Adjust the sizes in case of rounding issues
while len(train_indices) > train_size:
    # Move excess from train to test to maintain the size constraint
    train_indices, test_indices = train_indices[:-1], test_indices + [train_indices[-1]]

while len(test_indices) > test_size:
    # Move excess from test to train if necessary
    test_indices, train_indices = test_indices[:-1], train_indices + [test_indices[-1]]

# %%
batch_size = 20

train_dataset = Subset(dataset, train_indices)
test_dataset = Subset(dataset, test_indices)

train_loader = DataLoader(train_dataset, batch_size=batch_size, shuffle=True)
test_loader = DataLoader(test_dataset, batch_size=batch_size, shuffle=False)


device = torch.device("cuda")

### model initialization ###

learning_rate = 0.001
num_epochs = 50


# Define the CNN model (Phase identification classifier)
class CNNModel(nn.Module):
    def __init__(self):
        super(CNNModel, self).__init__()
        self.conv1 = nn.Conv2d(1, 8, kernel_size=5)  # 1st conv layer
        self.pool = nn.MaxPool2d(kernel_size=2, stride=2)  # Pooling layer
        self.conv2 = nn.Conv2d(8, 12, kernel_size=5)  # 2nd conv layer
        
        self.fc1 = nn.Linear(5 * 3 * 12, 300)  
        self.fc2 = nn.Linear(300, 2)  # Output layer

    def forward(self, x):
        # print(x.size())
        x = self.pool(self.conv1(x))
        x = self.pool(self.conv2(x))
        x = x.view(x.size(0), -1)  # Flatten the output for the fully connected layer
        x = self.fc1(x)
        x = self.fc2(x)

        return x

# Instantiate the model and loss function
model = CNNModel()
# criterion = nn.MSELoss()
criterion = nn.CrossEntropyLoss()

optimizer = optim.Adam(model.parameters(), lr=learning_rate)

# Training loop
for epoch in range(num_epochs):
    for i, (images, labels) in enumerate(train_loader):
        optimizer.zero_grad()
        outputs = model(images)
        loss = criterion(outputs, labels)
        loss.backward()
        optimizer.step()

        if (i+1) % 100 == 0:
            print(f"Epoch [{epoch+1}/{num_epochs}], Step [{i+1}/{len(train_loader)}], Loss: {loss.item():.4f}")
# Out:
# Epoch [1/50], Step [100/960], Loss: 0.4984
# Epoch [1/50], Step [200/960], Loss: 0.1894
# Epoch [1/50], Step [300/960], Loss: 0.3492
# Epoch [1/50], Step [400/960], Loss: 0.3231
# Epoch [1/50], Step [500/960], Loss: 0.2545
# Epoch [1/50], Step [600/960], Loss: 0.5522
# Epoch [1/50], Step [700/960], Loss: 0.1645
# Epoch [1/50], Step [800/960], Loss: 0.2104
# Epoch [1/50], Step [900/960], Loss: 0.3921
# Epoch [2/50], Step [100/960], Loss: 0.2799
# Epoch [2/50], Step [200/960], Loss: 0.5800
# Epoch [2/50], Step [300/960], Loss: 0.6295
# Epoch [2/50], Step [400/960], Loss: 0.3842
# Epoch [2/50], Step [500/960], Loss: 0.2324
# Epoch [2/50], Step [600/960], Loss: 0.0801
# Epoch [2/50], Step [700/960], Loss: 0.2353
# Epoch [2/50], Step [800/960], Loss: 0.2443
# Epoch [2/50], Step [900/960], Loss: 0.4900
# Epoch [3/50], Step [100/960], Loss: 0.2093
# Epoch [3/50], Step [200/960], Loss: 0.7630
# Epoch [3/50], Step [300/960], Loss: 0.2198
# Epoch [3/50], Step [400/960], Loss: 0.2448
# Epoch [3/50], Step [500/960], Loss: 0.8643
# Epoch [3/50], Step [600/960], Loss: 0.1844
# Epoch [3/50], Step [700/960], Loss: 0.1906
# Epoch [3/50], Step [800/960], Loss: 0.1303
# Epoch [3/50], Step [900/960], Loss: 0.2947
# Epoch [4/50], Step [100/960], Loss: 0.1743
# Epoch [4/50], Step [200/960], Loss: 0.1793
# Epoch [4/50], Step [300/960], Loss: 0.2567
# Epoch [48/50], Step [400/960], Loss: 0.2919
# Epoch [48/50], Step [500/960], Loss: 0.3728
# Epoch [48/50], Step [600/960], Loss: 0.1636
# Epoch [48/50], Step [700/960], Loss: 0.0786
# Epoch [48/50], Step [800/960], Loss: 0.2148
# Epoch [48/50], Step [900/960], Loss: 0.3034
# Epoch [49/50], Step [100/960], Loss: 0.1199
# Epoch [49/50], Step [200/960], Loss: 0.1117
# Epoch [49/50], Step [300/960], Loss: 0.0725
# Epoch [49/50], Step [400/960], Loss: 0.1680
# Epoch [49/50], Step [500/960], Loss: 0.1364
# Epoch [49/50], Step [600/960], Loss: 0.2053
# Epoch [49/50], Step [700/960], Loss: 0.1893
# Epoch [49/50], Step [800/960], Loss: 0.3212
# Epoch [49/50], Step [900/960], Loss: 0.1919
# Epoch [50/50], Step [100/960], Loss: 0.2082
# Epoch [50/50], Step [200/960], Loss: 0.0617
# Epoch [50/50], Step [300/960], Loss: 0.4422
# Epoch [50/50], Step [400/960], Loss: 0.3771
# Epoch [50/50], Step [500/960], Loss: 0.1692
# Epoch [50/50], Step [600/960], Loss: 0.4298
# Epoch [50/50], Step [700/960], Loss: 0.2925
# Epoch [50/50], Step [800/960], Loss: 0.1258
# Epoch [50/50], Step [900/960], Loss: 0.1278

# %%
# Testing train loop
model.eval()
correct = 0
total = 0
with torch.no_grad():
    for images, labels in train_loader:
        outputs = model(images)
        _, predicted = torch.max(outputs.data, 1)
        total += labels.size(0)
        correct += (predicted == labels).sum().item()
print(f"Accuracy on the train set: {(100 * correct / total):.2f}%")

# Testing loop
model.eval()
correct = 0
total = 0
with torch.no_grad():
    for images, labels in test_loader:
        outputs = model(images)
        _, predicted = torch.max(outputs.data, 1)
        total += labels.size(0)
        correct += (predicted == labels).sum().item()
print(f"Accuracy on the test set: {(100 * correct / total):.2f}%")
# Out:
# Accuracy on the train set: 92.92%
# Accuracy on the test set: 84.35%

# %%
### required qubits estimation ##############
# NN weights

numpy_weights = {}
nw_list = [] 
nw_list_normal = []
for name, param in model.state_dict().items():
    numpy_weights[name] = param.cpu().numpy()
for i in numpy_weights:
    nw_list.append(list(numpy_weights[i].flatten()))
for i in nw_list:
    for j in i:
        nw_list_normal.append(j)
print("# of NN parameters: ", len(nw_list_normal))
n_qubits = int(np.ceil(np.log2(len(nw_list_normal))))
print("Required qubit number: ", n_qubits)

n_qubit = n_qubits

#############################################
# Out:
# # of NN parameters:  57522
# Required qubit number:  16

# %%
### Some tool function definition ###########
def probs_to_weights(probs_):

    new_state_dict = {}
    data_iterator = probs_.view(-1)

    for name, param in CNNModel().state_dict().items():
        shape = param.shape
        num_elements = param.numel()
        chunk = data_iterator[:num_elements].reshape(shape)
        new_state_dict[name] = chunk
        data_iterator = data_iterator[num_elements:]
        
    return new_state_dict

def generate_qubit_states_torch(n_qubit):
    # Create a tensor of shape (2**n_qubit, n_qubit) with all possible combinations of 0 and 1
    all_states = torch.cartesian_prod(*[torch.tensor([-1, 1]) for _ in range(n_qubit)])
    return all_states

#############################################

### Main Learning-wise Hybridization model ##

class LewHybridNN(nn.Module):
    class QLayer(nn.Module):
        def __init__(self, n_blocks):
            super().__init__()
            self.n_wires = int(np.ceil(np.log2(len(nw_list_normal)))),
            self.n_wires = self.n_wires[0]
            self.n_blocks = n_blocks
            self.u3_layers = tq.QuantumModuleList()
            self.cu3_layers = tq.QuantumModuleList()
            # self.measure = tq.MeasureAll(tq.PauliZ)
            for _ in range(self.n_blocks):
                self.u3_layers.append(
                    tq.Op1QAllLayer(
                        op=tq.U3,
                        n_wires=self.n_wires,
                        has_params=True,
                        trainable=True,
                    )
                )
                self.cu3_layers.append(
                    tq.Op2QAllLayer(
                        op=tq.CU3,
                        n_wires=self.n_wires,
                        has_params=True,
                        trainable=True,
                        circular=True,
                    )
                )
                
        def forward(self):
            qdev = tq.QuantumDevice(
                n_wires=self.n_wires, bsz=1, device=next(self.parameters()).device
            )
            easy_scale_coeff = 2**(n_qubit-1)
            gamma = 0.1
            beta  = 0.8
            alpha = 0.3
            for k in range(self.n_blocks):
                self.u3_layers[k](qdev)
                self.cu3_layers[k](qdev)
                
            state_mag = qdev.get_states_1d().abs()[0] 
            state_mag = state_mag[:len(nw_list_normal)]
            x = torch.abs(state_mag) ** 2
            # x = torch.log(x)
            x = x.reshape(len(nw_list_normal),1)
            x = (beta*torch.tanh(gamma*easy_scale_coeff*x))**(alpha) 
            x = x - torch.mean(x)
            x.to(device)
            return x

        
        
    class MappingModel(nn.Module):
        def __init__(self, input_size, hidden_sizes, output_size):
            super().__init__()
            # Initialize layers: an input layer, multiple hidden layers, and an output layer
            self.input_layer = nn.Linear(input_size, hidden_sizes[0])
            self.hidden_layers = nn.ModuleList([nn.Linear(hidden_sizes[i], hidden_sizes[i+1]) for i in range(len(hidden_sizes)-1)])
            self.output_layer = nn.Linear(hidden_sizes[-1], output_size)
            
        def forward(self, X):
            # Ensure the input tensor is the same type as the weights
            X = X.type_as(self.input_layer.weight)
            X = self.input_layer(X)

            for hidden in self.hidden_layers:
                X = hidden(X)

            # Output layer with linear activation
            output = self.output_layer(X)
            return output

    def __init__(self):
        """
        Definition of the *dressed* layout.
        """
        super().__init__()
        self.MappingNetwork = self.MappingModel(n_qubit+1, [10, 20, 10], 1).to(device)  
        # self.MappingNetwork = self.ConvMappingModel()
        self.QuantumNN = self.QLayer(q_depth).to(device)   #arch={"n_blocks": q_depth})
    
    def forward(self, x):
        """
        Defining how tensors are supposed to move through the *dressed* quantum
        net.
        """
        device = x.device

        probs_ = self.QuantumNN()
        probs_ = probs_[:len(nw_list_normal)]
        
        # Generate qubit states using PyTorch
        qubit_states_torch = generate_qubit_states_torch(n_qubit)[:len(nw_list_normal)]
        qubit_states_torch = qubit_states_torch.to(device)

        # Combine qubit states with probability values using PyTorch
        combined_data_torch = torch.cat((qubit_states_torch, probs_), dim=1)
        combined_data_torch = combined_data_torch.reshape(len(nw_list_normal), 1, n_qubit+1)
        
        prob_val_post_processed = self.MappingNetwork(combined_data_torch)
        prob_val_post_processed = prob_val_post_processed - prob_val_post_processed.mean()
        
        ## Now we have generated the classical NN weights by a QNN + MM model with polylog number of parameters ! 
        state_dict = probs_to_weights(prob_val_post_processed)

        ######## 
            
        dtype = torch.float32  # Ensure all tensors are of this type
        
        # Convolution layer 1 parameters
        conv1_weight = state_dict['conv1.weight'].to(device).type(dtype)
        conv1_bias = state_dict['conv1.bias'].to(device).type(dtype)

        # Convolution layer 2 parameters
        conv2_weight = state_dict['conv2.weight'].to(device).type(dtype)
        conv2_bias = state_dict['conv2.bias'].to(device).type(dtype)

        # Fully connected layer 1 parameters
        fc1_weight = state_dict['fc1.weight'].to(device).type(dtype)
        fc1_bias = state_dict['fc1.bias'].to(device).type(dtype)

        # Fully connected layer 2 parameters
        fc2_weight = state_dict['fc2.weight'].to(device).type(dtype)
        fc2_bias = state_dict['fc2.bias'].to(device).type(dtype)
        
        
        # Convolution 1
        x = F.conv2d(x, conv1_weight, conv1_bias, stride=1)
        x = F.max_pool2d(x, kernel_size=2, stride=2)

        # Convolution 2
        x = F.conv2d(x, conv2_weight, conv2_bias, stride=1)
        x = F.max_pool2d(x, kernel_size=2, stride=2)

        # Flatten
        x = x.view(x.size(0), -1)

        # Fully connected 1
        x = F.linear(x, fc1_weight, fc1_bias)

        # Fully connected 2
        x = F.linear(x, fc2_weight, fc2_bias)

    
        return x

# %%
### Training setting ########################

step = 1e-4                 # Learning rate
batch_size = 100       # Number of samples for each training step
num_epochs = 50             # Number of training epochs
q_depth = 16             # Depth of the quantum circuit (number of variational layers)
gamma_lr_scheduler = 0.1    # Learning rate reduction applied every 10 epochs.
q_delta = 0.1              # Initial spread of random quantum weights

train_dataset = Subset(dataset, train_indices)
test_dataset = Subset(dataset, test_indices)

train_loader = DataLoader(train_dataset, batch_size=batch_size, shuffle=True)
test_loader = DataLoader(test_dataset, batch_size=batch_size, shuffle=False)



# Instantiate the model, move it to GPU, and set up loss function and optimizer
model = LewHybridNN().to(device)
criterion = nn.CrossEntropyLoss()

optimizer = optim.Adam(model.parameters(), lr=step, weight_decay=1e-5, eps=1e-6)
scheduler = optim.lr_scheduler.ReduceLROnPlateau(optimizer, 'min', patience = 5, verbose = True, factor = 0.5)  # 'min' because we're minimizing loss

num_trainable_params_MM = sum(p.numel() for p in LewHybridNN.MappingModel(n_qubit+1,  [10, 20, 10], 1).parameters() if p.requires_grad)
# num_trainable_params_MM = sum(p.numel() for p in LewHybridNN.ConvMappingModel().parameters() if p.requires_grad)
num_trainable_params = sum(p.numel() for p in model.parameters() if p.requires_grad)
print("# of trainable parameter in Mapping model: ", num_trainable_params_MM)
print("# of trainable parameter in QNN model: ", num_trainable_params - num_trainable_params_MM)
print("# of trainable parameter in full model: ", num_trainable_params)
# Out:
# # of trainable parameter in Mapping model:  621
# # of trainable parameter in QNN model:  1536
# # of trainable parameter in full model:  2157
# /home/jupyter/.local/lib/python3.10/site-packages/torch/optim/lr_scheduler.py:28: UserWarning: The verbose parameter is deprecated. Please use get_last_lr() to access the learning rate.
#   warnings.warn("The verbose parameter is deprecated. Please use get_last_lr() "

# %%
#############################################
### Training loop ###########################

### (Optional) Start from pretrained model ##
# model = torch.load('result_FF_mm_b1000_40_200_40/tq_mm_acc_70_bsf')
# model.eval()  # Set the model to evaluation mode
#############################################

loss_list = [] 
acc_list = [] 
acc_best = 0
for epoch in range(num_epochs):
    model.train()
    train_loss = 0
    for i, (images, labels) in enumerate(train_loader):
        correct = 0
        total = 0
        since_batch = time.time()
        
        images, labels = images.to(device), labels.to(device)  # Move data to GPU
        optimizer.zero_grad()
        # Forward pass
        outputs = model(images)
        # print("output: ", outputs)
        labels_one_hot = F.one_hot(labels, num_classes=2).float()
        _, predicted = torch.max(outputs.data, 1)
        total += labels.size(0)
        correct += (predicted == labels).sum().item()
        # Compute loss
        loss = criterion(outputs, labels_one_hot)
        # log_loss = torch.log(loss + 1e-6)
        
        loss_list.append(loss.cpu().detach().numpy())
        acc = 100 * correct / total
        acc_list.append(acc)
        train_loss += loss.cpu().detach().numpy()
        
        # np.array(loss_list).dump("result/TFIM_1x16/L16/loss_list.dat")
        # np.array(acc_list).dump("result/TFIM_1x16/L16/acc_list.dat")
        if acc > acc_best:
            #torch.save(model, 'result/TFIM_1x16/L16/tq_mm_acc_'+str(int(acc))+'_bsf')
            acc_best = acc
        # Backward pass and optimization
        loss.backward()
        
        optimizer.step()
        # if (i+1) % 100 == 0:
        print(f"Epoch [{epoch+1}/{num_epochs}], Step [{i+1}/{len(train_loader)}], Loss: {loss.item():.4f}, batch time: {time.time() - since_batch:.2f}, accuracy:  {(acc):.2f}%")
    
    train_loss /= len(train_loader)
    scheduler.step(train_loss)
    
#############################################
# Out:
# Epoch [1/50], Step [1/192], Loss: 48.9350, batch time: 1.39, accuracy:  82.00%
# Epoch [1/50], Step [2/192], Loss: 68.2635, batch time: 0.76, accuracy:  72.00%
# Epoch [1/50], Step [3/192], Loss: 48.9968, batch time: 0.75, accuracy:  78.00%
# Epoch [1/50], Step [4/192], Loss: 75.6771, batch time: 0.78, accuracy:  67.00%
# Epoch [1/50], Step [5/192], Loss: 46.7992, batch time: 0.78, accuracy:  79.00%
# Epoch [1/50], Step [6/192], Loss: 51.9777, batch time: 0.73, accuracy:  73.00%
# Epoch [1/50], Step [7/192], Loss: 49.5977, batch time: 0.75, accuracy:  74.00%
# Epoch [1/50], Step [8/192], Loss: 55.6697, batch time: 0.80, accuracy:  69.00%
# Epoch [1/50], Step [9/192], Loss: 54.7830, batch time: 0.74, accuracy:  72.00%
# Epoch [1/50], Step [10/192], Loss: 60.2635, batch time: 0.77, accuracy:  66.00%
# Epoch [1/50], Step [11/192], Loss: 34.9630, batch time: 0.77, accuracy:  77.00%
# Epoch [1/50], Step [12/192], Loss: 38.8197, batch time: 0.76, accuracy:  73.00%
# Epoch [1/50], Step [13/192], Loss: 42.3088, batch time: 0.77, accuracy:  71.00%
# Epoch [1/50], Step [14/192], Loss: 43.4433, batch time: 0.83, accuracy:  69.00%
# Epoch [1/50], Step [15/192], Loss: 45.1822, batch time: 0.70, accuracy:  67.00%
# Epoch [1/50], Step [16/192], Loss: 38.1030, batch time: 0.76, accuracy:  68.00%
# Epoch [1/50], Step [17/192], Loss: 44.0064, batch time: 0.77, accuracy:  63.00%
# Epoch [1/50], Step [18/192], Loss: 39.8967, batch time: 0.78, accuracy:  65.00%
# Epoch [1/50], Step [19/192], Loss: 32.1186, batch time: 0.76, accuracy:  67.00%
# Epoch [1/50], Step [20/192], Loss: 20.9134, batch time: 0.77, accuracy:  75.00%
# Epoch [1/50], Step [21/192], Loss: 22.2529, batch time: 0.78, accuracy:  68.00%
# Epoch [1/50], Step [22/192], Loss: 21.0417, batch time: 0.85, accuracy:  74.00%
# Epoch [1/50], Step [23/192], Loss: 22.1562, batch time: 0.70, accuracy:  60.00%
# Epoch [1/50], Step [24/192], Loss: 16.5860, batch time: 0.77, accuracy:  66.00%
# Epoch [1/50], Step [25/192], Loss: 20.9049, batch time: 0.77, accuracy:  63.00%
# Epoch [1/50], Step [26/192], Loss: 23.8800, batch time: 0.77, accuracy:  53.00%
# Epoch [1/50], Step [27/192], Loss: 17.6637, batch time: 0.77, accuracy:  62.00%
# Epoch [1/50], Step [28/192], Loss: 21.6433, batch time: 0.77, accuracy:  65.00%
# Epoch [1/50], Step [29/192], Loss: 17.2027, batch time: 0.77, accuracy:  63.00%
# Epoch [50/50], Step [39/192], Loss: 0.3718, batch time: 0.81, accuracy:  84.00%
# Epoch [50/50], Step [40/192], Loss: 0.4292, batch time: 0.68, accuracy:  79.00%
# Epoch [50/50], Step [41/192], Loss: 0.3624, batch time: 0.77, accuracy:  84.00%
# Epoch [50/50], Step [42/192], Loss: 0.4044, batch time: 0.75, accuracy:  84.00%
# Epoch [50/50], Step [43/192], Loss: 0.3493, batch time: 0.74, accuracy:  87.00%
# Epoch [50/50], Step [44/192], Loss: 0.3786, batch time: 0.86, accuracy:  86.00%
# Epoch [50/50], Step [45/192], Loss: 0.2892, batch time: 0.69, accuracy:  93.00%
# Epoch [50/50], Step [46/192], Loss: 0.3790, batch time: 0.80, accuracy:  85.00%
# Epoch [50/50], Step [47/192], Loss: 0.3838, batch time: 0.72, accuracy:  84.00%
# Epoch [50/50], Step [48/192], Loss: 0.4522, batch time: 0.86, accuracy:  74.00%
# Epoch [50/50], Step [49/192], Loss: 0.3599, batch time: 0.69, accuracy:  88.00%
# Epoch [50/50], Step [50/192], Loss: 0.3788, batch time: 0.83, accuracy:  83.00%
# Epoch [50/50], Step [51/192], Loss: 0.3999, batch time: 0.69, accuracy:  85.00%
# Epoch [50/50], Step [52/192], Loss: 0.3262, batch time: 0.77, accuracy:  89.00%
# Epoch [50/50], Step [53/192], Loss: 0.3905, batch time: 0.78, accuracy:  82.00%
# Epoch [50/50], Step [54/192], Loss: 0.4183, batch time: 0.76, accuracy:  79.00%
# Epoch [50/50], Step [55/192], Loss: 0.3155, batch time: 0.81, accuracy:  84.00%
# Epoch [50/50], Step [56/192], Loss: 0.3598, batch time: 0.75, accuracy:  84.00%
# Epoch [50/50], Step [57/192], Loss: 0.4268, batch time: 0.84, accuracy:  80.00%
# Epoch [50/50], Step [58/192], Loss: 0.3583, batch time: 0.68, accuracy:  88.00%
# Epoch [50/50], Step [59/192], Loss: 0.3667, batch time: 0.78, accuracy:  84.00%
# Epoch [50/50], Step [60/192], Loss: 0.3071, batch time: 0.77, accuracy:  85.00%
# Epoch [50/50], Step [61/192], Loss: 0.4606, batch time: 0.81, accuracy:  80.00%
# Epoch [50/50], Step [62/192], Loss: 0.3497, batch time: 0.75, accuracy:  84.00%
# Epoch [50/50], Step [63/192], Loss: 0.3729, batch time: 0.78, accuracy:  83.00%
# Epoch [50/50], Step [64/192], Loss: 0.3462, batch time: 0.70, accuracy:  90.00%
# Epoch [50/50], Step [65/192], Loss: 0.3710, batch time: 0.85, accuracy:  84.00%
# Epoch [50/50], Step [66/192], Loss: 0.3695, batch time: 0.70, accuracy:  80.00%
# Epoch [50/50], Step [67/192], Loss: 0.4496, batch time: 0.81, accuracy:  84.00%
# Epoch [50/50], Step [68/192], Loss: 0.3730, batch time: 0.76, accuracy:  87.00%
# Epoch [50/50], Step [69/192], Loss: 0.3301, batch time: 0.89, accuracy:  88.00%
# Epoch [50/50], Step [70/192], Loss: 0.2841, batch time: 0.67, accuracy:  88.00%
# Epoch [50/50], Step [71/192], Loss: 0.3599, batch time: 0.69, accuracy:  82.00%
# Epoch [50/50], Step [72/192], Loss: 0.4027, batch time: 0.76, accuracy:  80.00%
# Epoch [50/50], Step [73/192], Loss: 0.2563, batch time: 0.83, accuracy:  90.00%
# Epoch [50/50], Step [74/192], Loss: 0.3740, batch time: 0.71, accuracy:  84.00%
# Epoch [50/50], Step [75/192], Loss: 0.4559, batch time: 0.87, accuracy:  79.00%
# Epoch [50/50], Step [76/192], Loss: 0.4157, batch time: 0.67, accuracy:  83.00%
# Epoch [50/50], Step [77/192], Loss: 0.3836, batch time: 0.78, accuracy:  83.00%
# Epoch [50/50], Step [78/192], Loss: 0.3381, batch time: 0.78, accuracy:  85.00%
# Epoch [50/50], Step [79/192], Loss: 0.3757, batch time: 0.76, accuracy:  87.00%
# Epoch [50/50], Step [80/192], Loss: 0.3918, batch time: 0.78, accuracy:  81.00%
# Epoch [50/50], Step [81/192], Loss: 0.3721, batch time: 0.90, accuracy:  80.00%
# Epoch [50/50], Step [82/192], Loss: 0.3851, batch time: 0.70, accuracy:  83.00%
# Epoch [50/50], Step [83/192], Loss: 0.3769, batch time: 0.84, accuracy:  86.00%
# Epoch [50/50], Step [84/192], Loss: 0.4954, batch time: 0.82, accuracy:  78.00%
# Epoch [50/50], Step [85/192], Loss: 0.3772, batch time: 0.80, accuracy:  86.00%
# Epoch [50/50], Step [86/192], Loss: 0.3277, batch time: 0.72, accuracy:  87.00%
# Epoch [50/50], Step [87/192], Loss: 0.3386, batch time: 0.71, accuracy:  84.00%
# Epoch [50/50], Step [88/192], Loss: 0.3611, batch time: 0.67, accuracy:  80.00%
# Epoch [50/50], Step [89/192], Loss: 0.3988, batch time: 0.88, accuracy:  83.00%
# Epoch [50/50], Step [90/192], Loss: 0.3321, batch time: 0.68, accuracy:  85.00%
# Epoch [50/50], Step [91/192], Loss: 0.3771, batch time: 0.77, accuracy:  82.00%
# Epoch [50/50], Step [92/192], Loss: 0.3141, batch time: 0.76, accuracy:  88.00%
# Epoch [50/50], Step [93/192], Loss: 0.3704, batch time: 0.77, accuracy:  85.00%
# Epoch [50/50], Step [94/192], Loss: 0.3523, batch time: 0.77, accuracy:  82.00%
# Epoch [50/50], Step [95/192], Loss: 0.3730, batch time: 0.77, accuracy:  82.00%
# Epoch [50/50], Step [96/192], Loss: 0.5754, batch time: 0.76, accuracy:  77.00%
# Epoch [50/50], Step [97/192], Loss: 0.3564, batch time: 0.78, accuracy:  82.00%
# Epoch [50/50], Step [98/192], Loss: 0.4297, batch time: 0.76, accuracy:  82.00%
# Epoch [50/50], Step [99/192], Loss: 0.3599, batch time: 0.77, accuracy:  86.00%
# Epoch [50/50], Step [100/192], Loss: 0.4138, batch time: 0.76, accuracy:  82.00%
# Epoch [50/50], Step [101/192], Loss: 0.4229, batch time: 0.78, accuracy:  81.00%
# Epoch [50/50], Step [102/192], Loss: 0.4179, batch time: 0.76, accuracy:  79.00%
# Epoch [50/50], Step [103/192], Loss: 0.4045, batch time: 0.75, accuracy:  84.00%
# Epoch [50/50], Step [104/192], Loss: 0.5708, batch time: 0.82, accuracy:  75.00%
# Epoch [50/50], Step [105/192], Loss: 0.3901, batch time: 0.71, accuracy:  82.00%
# Epoch [50/50], Step [106/192], Loss: 0.3571, batch time: 0.78, accuracy:  83.00%
# Epoch [50/50], Step [107/192], Loss: 0.4536, batch time: 0.82, accuracy:  77.00%
# Epoch [50/50], Step [108/192], Loss: 0.4152, batch time: 0.71, accuracy:  84.00%
# Epoch [50/50], Step [109/192], Loss: 0.4062, batch time: 0.81, accuracy:  80.00%
# Epoch [50/50], Step [110/192], Loss: 0.4505, batch time: 0.74, accuracy:  76.00%
# Epoch [50/50], Step [111/192], Loss: 0.3789, batch time: 0.77, accuracy:  84.00%
# Epoch [50/50], Step [112/192], Loss: 0.3824, batch time: 0.77, accuracy:  87.00%
# Epoch [50/50], Step [113/192], Loss: 0.3835, batch time: 0.81, accuracy:  83.00%
# Epoch [50/50], Step [114/192], Loss: 0.3101, batch time: 0.73, accuracy:  88.00%
# Epoch [50/50], Step [115/192], Loss: 0.4197, batch time: 0.91, accuracy:  79.00%
# Epoch [50/50], Step [116/192], Loss: 0.3615, batch time: 0.71, accuracy:  88.00%
# Epoch [50/50], Step [117/192], Loss: 0.5177, batch time: 0.72, accuracy:  79.00%
# Epoch [50/50], Step [118/192], Loss: 0.3709, batch time: 0.78, accuracy:  84.00%
# Epoch [50/50], Step [119/192], Loss: 0.4450, batch time: 0.77, accuracy:  77.00%
# Epoch [50/50], Step [120/192], Loss: 0.4298, batch time: 0.81, accuracy:  79.00%
# Epoch [50/50], Step [121/192], Loss: 0.5233, batch time: 0.69, accuracy:  71.00%
# Epoch [50/50], Step [122/192], Loss: 0.4246, batch time: 0.82, accuracy:  83.00%
# Epoch [50/50], Step [123/192], Loss: 0.3731, batch time: 0.82, accuracy:  83.00%
# Epoch [50/50], Step [124/192], Loss: 0.3428, batch time: 0.68, accuracy:  82.00%
# Epoch [50/50], Step [125/192], Loss: 0.3378, batch time: 0.81, accuracy:  82.00%
# Epoch [50/50], Step [126/192], Loss: 0.3629, batch time: 0.76, accuracy:  87.00%
# Epoch [50/50], Step [127/192], Loss: 0.4817, batch time: 0.73, accuracy:  82.00%
# Epoch [50/50], Step [128/192], Loss: 0.4858, batch time: 0.78, accuracy:  78.00%
# Epoch [50/50], Step [129/192], Loss: 0.2972, batch time: 0.81, accuracy:  85.00%
# Epoch [50/50], Step [130/192], Loss: 0.4699, batch time: 0.85, accuracy:  75.00%
# Epoch [50/50], Step [131/192], Loss: 0.3792, batch time: 0.68, accuracy:  82.00%
# Epoch [50/50], Step [132/192], Loss: 0.4577, batch time: 0.70, accuracy:  79.00%
# Epoch [50/50], Step [133/192], Loss: 0.3555, batch time: 0.78, accuracy:  87.00%
# Epoch [50/50], Step [134/192], Loss: 0.3570, batch time: 0.75, accuracy:  86.00%
# Epoch [50/50], Step [135/192], Loss: 0.4312, batch time: 0.77, accuracy:  82.00%
# Epoch [50/50], Step [136/192], Loss: 0.3729, batch time: 0.77, accuracy:  84.00%
# Epoch [50/50], Step [137/192], Loss: 0.4088, batch time: 0.81, accuracy:  79.00%
# Epoch [50/50], Step [138/192], Loss: 0.4509, batch time: 0.72, accuracy:  81.00%
# Epoch [50/50], Step [139/192], Loss: 0.6173, batch time: 0.83, accuracy:  75.00%
# Epoch [50/50], Step [140/192], Loss: 0.3859, batch time: 0.74, accuracy:  84.00%
# Epoch [50/50], Step [141/192], Loss: 0.3777, batch time: 0.72, accuracy:  82.00%
# Epoch [50/50], Step [142/192], Loss: 0.3890, batch time: 0.83, accuracy:  84.00%
# Epoch [50/50], Step [143/192], Loss: 0.4052, batch time: 0.82, accuracy:  86.00%
# Epoch [50/50], Step [144/192], Loss: 0.4021, batch time: 0.69, accuracy:  82.00%
# Epoch [50/50], Step [145/192], Loss: 0.4404, batch time: 0.73, accuracy:  85.00%
# Epoch [50/50], Step [146/192], Loss: 0.4202, batch time: 0.79, accuracy:  82.00%
# Epoch [50/50], Step [147/192], Loss: 0.3861, batch time: 0.76, accuracy:  84.00%
# Epoch [50/50], Step [148/192], Loss: 0.3145, batch time: 0.76, accuracy:  88.00%
# Epoch [50/50], Step [149/192], Loss: 0.4997, batch time: 0.77, accuracy:  78.00%
# Epoch [50/50], Step [150/192], Loss: 0.4160, batch time: 0.84, accuracy:  81.00%
# Epoch [50/50], Step [151/192], Loss: 0.2903, batch time: 0.69, accuracy:  89.00%
# Epoch [50/50], Step [152/192], Loss: 0.3981, batch time: 0.79, accuracy:  81.00%
# Epoch [50/50], Step [153/192], Loss: 0.3210, batch time: 0.84, accuracy:  89.00%
# Epoch [50/50], Step [154/192], Loss: 0.4085, batch time: 0.68, accuracy:  80.00%
# Epoch [50/50], Step [155/192], Loss: 0.3085, batch time: 0.82, accuracy:  86.00%
# Epoch [50/50], Step [156/192], Loss: 0.3551, batch time: 0.81, accuracy:  85.00%
# Epoch [50/50], Step [157/192], Loss: 0.4452, batch time: 0.70, accuracy:  82.00%
# Epoch [50/50], Step [158/192], Loss: 0.2871, batch time: 0.75, accuracy:  87.00%
# Epoch [50/50], Step [159/192], Loss: 0.2890, batch time: 0.77, accuracy:  87.00%
# Epoch [50/50], Step [160/192], Loss: 0.3590, batch time: 0.77, accuracy:  83.00%
# Epoch [50/50], Step [161/192], Loss: 0.4442, batch time: 0.79, accuracy:  81.00%
# Epoch [50/50], Step [162/192], Loss: 0.3291, batch time: 0.78, accuracy:  83.00%
# Epoch [50/50], Step [163/192], Loss: 0.2820, batch time: 0.85, accuracy:  91.00%
# Epoch [50/50], Step [164/192], Loss: 0.4754, batch time: 0.69, accuracy:  79.00%
# Epoch [50/50], Step [165/192], Loss: 0.4964, batch time: 0.79, accuracy:  74.00%
# Epoch [50/50], Step [166/192], Loss: 0.5086, batch time: 0.76, accuracy:  79.00%
# Epoch [50/50], Step [167/192], Loss: 0.4120, batch time: 0.83, accuracy:  83.00%
# Epoch [50/50], Step [168/192], Loss: 0.3983, batch time: 0.68, accuracy:  81.00%
# Epoch [50/50], Step [169/192], Loss: 0.3729, batch time: 0.77, accuracy:  86.00%
# Epoch [50/50], Step [170/192], Loss: 0.4587, batch time: 0.80, accuracy:  79.00%
# Epoch [50/50], Step [171/192], Loss: 0.3754, batch time: 0.74, accuracy:  85.00%
# Epoch [50/50], Step [172/192], Loss: 0.2902, batch time: 0.79, accuracy:  88.00%
# Epoch [50/50], Step [173/192], Loss: 0.5082, batch time: 0.77, accuracy:  77.00%
# Epoch [50/50], Step [174/192], Loss: 0.4535, batch time: 0.81, accuracy:  79.00%
# Epoch [50/50], Step [175/192], Loss: 0.4009, batch time: 0.70, accuracy:  80.00%
# Epoch [50/50], Step [176/192], Loss: 0.4434, batch time: 0.79, accuracy:  79.00%
# Epoch [50/50], Step [177/192], Loss: 0.4113, batch time: 0.77, accuracy:  79.00%
# Epoch [50/50], Step [178/192], Loss: 0.3326, batch time: 0.75, accuracy:  90.00%
# Epoch [50/50], Step [179/192], Loss: 0.4334, batch time: 0.77, accuracy:  79.00%
# Epoch [50/50], Step [180/192], Loss: 0.4145, batch time: 0.79, accuracy:  83.00%
# Epoch [50/50], Step [181/192], Loss: 0.3759, batch time: 0.76, accuracy:  88.00%
# Epoch [50/50], Step [182/192], Loss: 0.4453, batch time: 0.76, accuracy:  78.00%
# Epoch [50/50], Step [183/192], Loss: 0.4676, batch time: 0.77, accuracy:  79.00%
# Epoch [50/50], Step [184/192], Loss: 0.3655, batch time: 0.76, accuracy:  84.00%
# Epoch [50/50], Step [185/192], Loss: 0.3426, batch time: 0.89, accuracy:  84.00%
# Epoch [50/50], Step [186/192], Loss: 0.3099, batch time: 0.69, accuracy:  86.00%
# Epoch [50/50], Step [187/192], Loss: 0.3232, batch time: 0.72, accuracy:  87.00%
# Epoch [50/50], Step [188/192], Loss: 0.3033, batch time: 0.76, accuracy:  88.00%
# Epoch [50/50], Step [189/192], Loss: 0.3784, batch time: 0.77, accuracy:  86.00%
# Epoch [50/50], Step [190/192], Loss: 0.3780, batch time: 0.77, accuracy:  86.00%
# Epoch [50/50], Step [191/192], Loss: 0.3782, batch time: 0.79, accuracy:  82.00%
# Epoch [50/50], Step [192/192], Loss: 0.4894, batch time: 0.75, accuracy:  79.00%

# %%
# Testing train loop
model.eval()
correct = 0
total = 0
loss_train_list = []
with torch.no_grad():
    for images, labels in train_loader:
        images, labels = images.to(device), labels.to(device)  # Move data to GPU
        outputs = model(images)
        loss_train = criterion(outputs, labels).cpu().detach().numpy()
        loss_train_list.append(loss_train)
        _, predicted = torch.max(outputs.data, 1)
        total += labels.size(0)
        correct += (predicted == labels).sum().item()

print(f"Accuracy on the train set: {(100 * correct / total):.2f}%")
print(f"Loss on the train set: {np.mean(loss_train_list):.2f}")
# Out:
# Accuracy on the train set: 83.13%
# Loss on the train set: 0.39

# %%
# Testing loop
model.eval()
correct = 0
total = 0
loss_test_list = []

with torch.no_grad():
    for images, labels in test_loader:
        images, labels = images.to(device), labels.to(device)  # Move data to GPU
        outputs = model(images)
        loss_test = criterion(outputs, labels).cpu().detach().numpy()
        loss_test_list.append(loss_test)

        _, predicted = torch.max(outputs.data, 1)
        total += labels.size(0)
        correct += (predicted == labels).sum().item()


print(f"Accuracy on the test set: {(100 * correct / total):.2f}%")
print(f"Loss on the test set: {np.mean(loss_test_list):.2f}")

print("Generalization error:", np.mean(loss_test_list) - np.mean(loss_train_list))
# Out:
# Accuracy on the test set: 86.94%
# Loss on the test set: 0.33
# Generalization error: -0.060159624
